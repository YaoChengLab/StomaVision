# %% [markdown]
# ### Extract file names from dataset

# %%
import os

dataset_dir = "/mnt/linux/abrc/abrc/dataset/stomaVDP"
dataset_name = "label-Leafnet-and-others"

img_extention = ["jpg", "png", "tif"]
parse_dirs = ["train", "val"]

for d in parse_dirs:
    img_list = os.listdir(os.path.join(dataset_dir, dataset_name, "images", d))
    output_filename = os.path.join(dataset_dir, dataset_name, d + ".txt")

    # clear data in the output_file
    with open(output_filename, "w") as f:
        pass

    for idx, img in enumerate(img_list):
        if img.split(".")[-1] in img_extention:
            print(img)
            with open(output_filename, "a") as f:
                f.write(os.path.join("./images", d, img))
                if idx < len(img_list) - 1:
                    f.write("\n")

print("file name extraction complete......")
# Out:
# BE_20X013.jpg
# 10441.jpg
# p_tr_38.png
# 10090.jpg
# c_tr_87_cut_want.jpg
# u_tr_184.png
# u_tr_26.png
# 107.jpg
# p_tr_63.png
# u_tr_42.png
# c_tr_99_cut_want.jpg
# u_tr_74.png
# u_tr_59.png
# p_tr_68.png
# 10060.jpg
# 9999.jpg
# u_tr_227.png
# C1L004.jpg
# c_tr_154_cut_want.jpg
# c_tr_13_cut_want.jpg
# u_tr_283.png
# 31.jpg
# c_tr_159_cut_want.jpg
# u_tr_54.png
# u_tr_46.png
# p_tr_57.png
# c_tr_62_cut_want.jpg
# u_tr_118.png
# u_tr_28.png
# C1L003.jpg
# c_tr_105_cut_want.jpg
# 56.jpg
# u_tr_39.png
# 1_c_tr_6_cut_want.jpg
# u_tr_72.png
# C1L008.jpg
# BE_20X012.jpg
# p_tr_91.png
# c_tr_65_cut_want.jpg
# BE_20X009.jpg
# CK001.jpg
# u_tr_12.png
# 90.jpg
# p_tr_66.png
# p_tr_4.png
# u_tr_222.png
# 12.jpg
# c_tr_24_cut_want.jpg
# u_tr_293.png
# C1L009.jpg
# p_tr_52.png
# u_tr_95.png
# c_tr_30_cut_want.jpg
# c_tr_124_cut_want.jpg
# 12782.jpg
# p_tr_33.png
# c_tr_176_cut_want.jpg
# u_tr_7.png
# p_tr_83.png
# u_tr_290.png
# 15.jpg
# p_tr_98.png
# 186.jpg
# 10203.jpg
# p_tr_58.png
# 1.jpg
# 51.jpg
# u_tr_238.png
# c_tr_70_cut_want.jpg
# c_tr_56_cut_want.jpg
# p_tr_74.png
# 10221.jpg
# p_tr_43.png
# p_tr_116.png
# u_tr_84.png
# 10473.jpg
# u_tr_242.png
# c_tr_86_cut_want.jpg
# 35.jpg
# 36.jpg
# 10393.jpg
# CK002.jpg
# u_tr_121.png
# u_tr_159.png
# 89.jpg
# p_tr_112.png
# p_tr_106.png
# 10425.jpg
# c_tr_32_cut_want.jpg
# u_tr_209.png
# p_tr_70.png
# c_tr_31_cut_want.jpg
# u_tr_294.png
# BE_20X006.jpg
# 13.jpg
# p_tr_30.png
# p_tr_56.png
# p_tr_22.png
# u_tr_170.png
# u_tr_57.png
# p_tr_85.png
# u_tr_0.png
# c_tr_73_cut_want.jpg
# C1L001.jpg
# 21.jpg
# u_tr_212.png
# u_tr_45.png
# CK005.jpg
# p_tr_53.png
# 190.jpg
# BE_20X001.jpg
# c_tr_101_cut_want.jpg
# 10306.jpg
# u_tr_20.png
# 10459.jpg
# c_tr_122_cut_want.jpg
# p_tr_15.png
# 5.jpg
# p_tr_117.png
# p_tr_60.png
# 10253.jpg
# c_tr_36_cut_want.jpg
# u_tr_55.png
# u_tr_138.png
# u_tr_292.png
# u_tr_169.png
# 34.jpg
# u_tr_82.png
# u_tr_279.png
# c_tr_35_cut_want.jpg
# u_tr_3.png
# 37.jpg
# 12750.jpg
# 8.jpg
# c_tr_129_cut_want.jpg
# u_tr_241.png
# u_tr_133.png
# p_tr_21.png
# p_tr_34.png
# 10083.jpg
# c_tr_41_cut_want.jpg
# u_tr_246.png
# CK007.jpg
# u_tr_281.png
# 10142.jpg
# BE_20X014.jpg
# c_tr_67_cut_want.jpg
# c_tr_25_cut_want.jpg
# u_tr_69.png
# p_tr_47.png
# u_tr_15.png
# c_tr_52_cut_want.jpg
# BE_20X011.jpg
# c_tr_97_cut_want.jpg
# c_tr_64_cut_want.jpg
# c_tr_10_cut_want.jpg
# 10052.jpg
# c_tr_115_cut_want.jpg
# 10269.jpg
# C1L007.jpg
# u_tr_274.png
# u_tr_236.png
# p_tr_7.png
# 10181.jpg
# 12646.jpg
# p_tr_0.png
# u_tr_245.png
# u_tr_299.png
# u_tr_151.png
# u_tr_178.png
# c_tr_5_cut_want.jpg
# c_tr_139_cut_want.jpg
# p_tr_16.png
# p_tr_71.png
# 150.jpg
# u_tr_179.png
# c_tr_75_cut_want.jpg
# 10356.jpg
# 33.jpg
# 10333.jpg
# u_tr_113.png
# C1L005.jpg
# u_tr_119.png
# p_tr_113.png
# p_tr_37.png
# BE_20X008.jpg
# 10294.jpg
# 12729.jpg
# p_tr_103.png
# 50.jpg
# 59.jpg
# 177.jpg
# 27.jpg
# c_tr_131_cut_want.jpg
# C1L002.jpg
# 197.jpg
# BE_20X003.jpg
# CK006.jpg
# BE_20X010.jpg
# p_tr_102.png
# c_tr_121_cut_want.jpg
# c_tr_91_cut_want.jpg
# p_tr_79.png
# p_tr_61.png
# C1L010.jpg
# p_tr_10.png
# c_tr_51_cut_want.jpg
# C1L006.jpg
# 182.jpg
# p_tr_44.png
# u_tr_160.png
# u_tr_210.png
# c_tr_117_cut_want.jpg
# p_tr_36.png
# c_tr_158_cut_want.jpg
# p_tr_35.png
# CK004.jpg
# u_tr_149.png
# 96.jpg
# c_tr_68_cut_want.jpg
# 42.jpg
# p_tr_115.png
# BE_20X005.jpg
# 10106.jpg
# BE_20X007.jpg
# u_tr_80.png
# 39.jpg
# u_tr_64.png
# BE_20X015.jpg
# BE_20X002.jpg
# u_tr_277.png
# u_tr_215.png
# CK003.jpg
# BE_20X004.jpg
# 10394.jpg
# file name extraction complete......

# %% [markdown]
# ### Convert Labels from COCO JSON instance to Yolov7 compatible polygon label format

# %%
import os, json, shutil

dataset_dir = "/mnt/linux/abrc/abrc/dataset/stomaVDP"
dataset_name = "label-Leafnet-and-others"

img_extention = ["jpg", "png", "tif"]
parse_dirs = ["train", "val"]

for d in parse_dirs:
    print(f"Start extracting data in {d}........")
    # Load label JSON file
    orig_annotations = None
    with open(
        os.path.join(dataset_dir, dataset_name, "labels", f"labels_{d}.json"), "r"
    ) as f_input:
        orig_annotations = json.load(f_input)

    dir = os.path.join(dataset_dir, dataset_name, "labels", d)
    CHECK_FOLDER = os.path.isdir(dir)

    if not CHECK_FOLDER:  # If folder doesn't exist, then create it.
        os.makedirs(os.path.join(dir, "seg"))
        os.makedirs(os.path.join(dir, "det"))
        print("created folder : ", dir)
    else:  # Reset folder if it exists.
        print(dir, "folder already exists.")
        shutil.rmtree(dir, ignore_errors=True)
        print("delete folder : ", dir)
        os.makedirs(os.path.join(dir, "seg"))
        os.makedirs(os.path.join(dir, "det"))
        print("created folder : ", dir)

    # Iterate through images in the JSON file
    for i, img in enumerate(orig_annotations):
        # Save Yolov7 annotation for instance segmentation
        output_filename = img["file_name"].split("/")[-1]  # get image name
        output_filename = os.path.splitext(output_filename)[0]  # remove extension
        output_filename = os.path.join(
            dataset_dir, dataset_name, "labels", d, f"{output_filename}.txt"
        )  # get full file name

        print(
            f"[{i+1}/{len(orig_annotations)}] extract and load seg annotations to: {output_filename}"
        )

        x_max = img["width"]
        y_max = img["height"]

        # Prepare and save segmentation annotations
        with open(output_filename, "w") as f_output:
            # iterate through annotations in each image.
            for idx, anno in enumerate(img["annotations"]):
                output = ""  # reset output
                output = output + str(anno["category_id"]) + " "  # add category id
                # save segmentation
                for idy, num in enumerate(anno["segmentation"][0]):
                    # normalise annotation
                    if idy % 2 == 0:  # odd number
                        output = output + str(round(num / x_max, 6))
                        if num / x_max > 1:
                            print(f"X wrong!!!: x={num}, xmax={x_max}")
                    else:  # even number
                        output = output + str(round(num / y_max, 6))
                        if num / y_max > 1:
                            print(f"Y wrong!!!: y={num}, ymax={y_max}")
                    if idy < len(anno["segmentation"][0]) - 1:
                        output = output + " "
                if idx < len(img["annotations"]) - 1:
                    output = output + "\n"
                f_output.write(output)

        # Save Yolov7 annotation for object detection
        output_filename = img["file_name"].split("/")[-1]  # get image name
        output_filename = os.path.splitext(output_filename)[0]  # remove extension
        output_filename = os.path.join(
            dataset_dir, dataset_name, "labels", d, "det", f"{output_filename}.txt"
        )  # get full file name

        print(
            f"[{i+1}/{len(orig_annotations)}] extract and load det annotations to: {output_filename}"
        )

        x_max = img["width"]
        y_max = img["height"]

        # Prepare and save detection annotations
        with open(output_filename, "w") as f_output:
            # iterate through annotations in each image.
            for idx, anno in enumerate(img["annotations"]):
                # reset output
                output = ""

                """
                Bbox annotation in Detectron2 is:
                anno['bbox'][0]: left top x
                anno['bbox'][1]: left top y
                anno['bbox'][1]: right bottom x
                anno['bbox'][1]: right bottom y
                """
                x_0 = anno["bbox"][0]
                y_0 = anno["bbox"][1]
                x_1 = anno["bbox"][2]
                y_1 = anno["bbox"][3]

                # add category id
                output = output + str(anno["category_id"]) + " "

                # add centre x axis
                x_centre = round((x_0 + x_1) / (2 * x_max), 6)
                if x_centre > 1:
                    print(f"X centre is wrong!!! centre_x={x_centre}, xmax={x_max}")
                output = output + str(x_centre) + " "

                # add centre y axis
                y_centre = round((y_0 + y_1) / (2 * y_max), 6)
                if y_centre > 1:
                    print(f"Y centre is wrong!!!: centre_x={y_centre}, ymax={y_max}")
                output = output + str(y_centre) + " "

                # add width
                width = round((x_1 - x_0) / (x_max), 6)
                if (width / 2) + x_centre > x_max:
                    print(f"width is wrong: width={width}, xmax={x_max}")
                if width < 0:
                    print(f"width is minus: width={width}, xmax={x_max}")
                output = output + str(width) + " "

                # add height
                height = round((y_1 - y_0) / (y_max), 6)
                if (height / 2) + y_centre > y_max:
                    print(f"width is wrong: height={height}, xmax={y_max}")
                if height < 0:
                    print(f"height is minus: width={height}, xmax={y_max}")
                output = output + str(height)

                if idx < len(img["annotations"]) - 1:
                    output = output + "\n"
                f_output.write(output)
# Out:
# Start extracting data in train........
# created folder :  /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train
# [1/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_97_cut_want.txt
# [1/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_97_cut_want.txt
# [2/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/10294.txt
# [2/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/10294.txt
# [3/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/10425.txt
# [3/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/10425.txt
# [4/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_75_cut_want.txt
# [4/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_75_cut_want.txt
# [5/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/C1L007.txt
# [5/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/C1L007.txt
# [6/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/u_tr_119.txt
# [6/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/u_tr_119.txt
# [7/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/p_tr_38.txt
# [7/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/p_tr_38.txt
# [8/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_159_cut_want.txt
# [8/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_159_cut_want.txt
# [9/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/51.txt
# [9/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/51.txt
# [10/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/p_tr_22.txt
# [10/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/p_tr_22.txt
# [11/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/u_tr_290.txt
# [11/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/u_tr_290.txt
# [12/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/56.txt
# X wrong!!!: x=232812.0, xmax=3840
# Y wrong!!!: y=6390.0, ymax=2748
# X wrong!!!: x=232771.0, xmax=3840
# Y wrong!!!: y=6761.0, ymax=2748
# X wrong!!!: x=232650.0, xmax=3840
# Y wrong!!!: y=7130.0, ymax=2748
# X wrong!!!: x=232449.0, xmax=3840
# Y wrong!!!: y=7493.0, ymax=2748
# X wrong!!!: x=232170.0, xmax=3840
# Y wrong!!!: y=7847.0, ymax=2748
# X wrong!!!: x=231815.0, xmax=3840
# Y wrong!!!: y=8190.0, ymax=2748
# X wrong!!!: x=231386.0, xmax=3840
# Y wrong!!!: y=8520.0, ymax=2748
# X wrong!!!: x=230887.0, xmax=3840
# Y wrong!!!: y=8833.0, ymax=2748
# X wrong!!!: x=230321.0, xmax=3840
# Y wrong!!!: y=9128.0, ymax=2748
# X wrong!!!: x=229694.0, xmax=3840
# Y wrong!!!: y=9402.0, ymax=2748
# X wrong!!!: x=229009.0, xmax=3840
# Y wrong!!!: y=9653.0, ymax=2748
# X wrong!!!: x=228272.0, xmax=3840
# Y wrong!!!: y=9880.0, ymax=2748
# X wrong!!!: x=227489.0, xmax=3840
# Y wrong!!!: y=10079.0, ymax=2748
# X wrong!!!: x=226665.0, xmax=3840
# Y wrong!!!: y=10251.0, ymax=2748
# X wrong!!!: x=225807.0, xmax=3840
# Y wrong!!!: y=10393.0, ymax=2748
# X wrong!!!: x=224921.0, xmax=3840
# Y wrong!!!: y=10505.0, ymax=2748
# X wrong!!!: x=224015.0, xmax=3840
# Y wrong!!!: y=10585.0, ymax=2748
# X wrong!!!: x=223094.0, xmax=3840
# Y wrong!!!: y=10634.0, ymax=2748
# X wrong!!!: x=222166.0, xmax=3840
# Y wrong!!!: y=10650.0, ymax=2748
# X wrong!!!: x=221238.0, xmax=3840
# Y wrong!!!: y=10634.0, ymax=2748
# X wrong!!!: x=220317.0, xmax=3840
# Y wrong!!!: y=10585.0, ymax=2748
# X wrong!!!: x=219411.0, xmax=3840
# Y wrong!!!: y=10505.0, ymax=2748
# X wrong!!!: x=218525.0, xmax=3840
# Y wrong!!!: y=10393.0, ymax=2748
# X wrong!!!: x=217667.0, xmax=3840
# Y wrong!!!: y=10251.0, ymax=2748
# X wrong!!!: x=216843.0, xmax=3840
# Y wrong!!!: y=10079.0, ymax=2748
# X wrong!!!: x=216060.0, xmax=3840
# Y wrong!!!: y=9880.0, ymax=2748
# X wrong!!!: x=215323.0, xmax=3840
# Y wrong!!!: y=9653.0, ymax=2748
# X wrong!!!: x=214638.0, xmax=3840
# Y wrong!!!: y=9402.0, ymax=2748
# X wrong!!!: x=214011.0, xmax=3840
# Y wrong!!!: y=9128.0, ymax=2748
# X wrong!!!: x=213445.0, xmax=3840
# Y wrong!!!: y=8833.0, ymax=2748
# X wrong!!!: x=212946.0, xmax=3840
# Y wrong!!!: y=8520.0, ymax=2748
# X wrong!!!: x=212517.0, xmax=3840
# Y wrong!!!: y=8190.0, ymax=2748
# X wrong!!!: x=212162.0, xmax=3840
# Y wrong!!!: y=7847.0, ymax=2748
# X wrong!!!: x=211883.0, xmax=3840
# Y wrong!!!: y=7493.0, ymax=2748
# X wrong!!!: x=211682.0, xmax=3840
# Y wrong!!!: y=7130.0, ymax=2748
# X wrong!!!: x=211561.0, xmax=3840
# Y wrong!!!: y=6761.0, ymax=2748
# X wrong!!!: x=211520.0, xmax=3840
# Y wrong!!!: y=6390.0, ymax=2748
# X wrong!!!: x=211561.0, xmax=3840
# Y wrong!!!: y=6019.0, ymax=2748
# X wrong!!!: x=211682.0, xmax=3840
# Y wrong!!!: y=5650.0, ymax=2748
# X wrong!!!: x=211883.0, xmax=3840
# Y wrong!!!: y=5287.0, ymax=2748
# X wrong!!!: x=212162.0, xmax=3840
# Y wrong!!!: y=4933.0, ymax=2748
# X wrong!!!: x=212517.0, xmax=3840
# Y wrong!!!: y=4590.0, ymax=2748
# X wrong!!!: x=212946.0, xmax=3840
# Y wrong!!!: y=4260.0, ymax=2748
# X wrong!!!: x=213445.0, xmax=3840
# Y wrong!!!: y=3947.0, ymax=2748
# X wrong!!!: x=214011.0, xmax=3840
# Y wrong!!!: y=3652.0, ymax=2748
# X wrong!!!: x=214638.0, xmax=3840
# Y wrong!!!: y=3378.0, ymax=2748
# X wrong!!!: x=215323.0, xmax=3840
# Y wrong!!!: y=3127.0, ymax=2748
# X wrong!!!: x=216060.0, xmax=3840
# Y wrong!!!: y=2900.0, ymax=2748
# X wrong!!!: x=216843.0, xmax=3840
# X wrong!!!: x=217667.0, xmax=3840
# X wrong!!!: x=218525.0, xmax=3840
# X wrong!!!: x=219411.0, xmax=3840
# X wrong!!!: x=220317.0, xmax=3840
# X wrong!!!: x=221238.0, xmax=3840
# X wrong!!!: x=222166.0, xmax=3840
# X wrong!!!: x=223094.0, xmax=3840
# X wrong!!!: x=224015.0, xmax=3840
# X wrong!!!: x=224921.0, xmax=3840
# X wrong!!!: x=225807.0, xmax=3840
# X wrong!!!: x=226665.0, xmax=3840
# X wrong!!!: x=227489.0, xmax=3840
# X wrong!!!: x=228272.0, xmax=3840
# Y wrong!!!: y=2900.0, ymax=2748
# X wrong!!!: x=229009.0, xmax=3840
# Y wrong!!!: y=3127.0, ymax=2748
# X wrong!!!: x=229694.0, xmax=3840
# Y wrong!!!: y=3378.0, ymax=2748
# X wrong!!!: x=230321.0, xmax=3840
# Y wrong!!!: y=3652.0, ymax=2748
# X wrong!!!: x=230887.0, xmax=3840
# Y wrong!!!: y=3947.0, ymax=2748
# X wrong!!!: x=231386.0, xmax=3840
# Y wrong!!!: y=4260.0, ymax=2748
# X wrong!!!: x=231815.0, xmax=3840
# Y wrong!!!: y=4590.0, ymax=2748
# X wrong!!!: x=232170.0, xmax=3840
# Y wrong!!!: y=4933.0, ymax=2748
# X wrong!!!: x=232449.0, xmax=3840
# Y wrong!!!: y=5287.0, ymax=2748
# X wrong!!!: x=232650.0, xmax=3840
# Y wrong!!!: y=5650.0, ymax=2748
# X wrong!!!: x=232771.0, xmax=3840
# Y wrong!!!: y=6019.0, ymax=2748
# X wrong!!!: x=232812.0, xmax=3840
# Y wrong!!!: y=6390.0, ymax=2748
# X wrong!!!: x=276820.0, xmax=3840
# Y wrong!!!: y=12071.0, ymax=2748
# X wrong!!!: x=276785.0, xmax=3840
# Y wrong!!!: y=12380.0, ymax=2748
# X wrong!!!: x=276680.0, xmax=3840
# Y wrong!!!: y=12687.0, ymax=2748
# X wrong!!!: x=276506.0, xmax=3840
# Y wrong!!!: y=12990.0, ymax=2748
# X wrong!!!: x=276264.0, xmax=3840
# Y wrong!!!: y=13285.0, ymax=2748
# X wrong!!!: x=275956.0, xmax=3840
# Y wrong!!!: y=13571.0, ymax=2748
# X wrong!!!: x=275584.0, xmax=3840
# Y wrong!!!: y=13846.0, ymax=2748
# X wrong!!!: x=275151.0, xmax=3840
# Y wrong!!!: y=14107.0, ymax=2748
# X wrong!!!: x=274661.0, xmax=3840
# Y wrong!!!: y=14353.0, ymax=2748
# X wrong!!!: x=274117.0, xmax=3840
# Y wrong!!!: y=14581.0, ymax=2748
# X wrong!!!: x=273524.0, xmax=3840
# Y wrong!!!: y=14790.0, ymax=2748
# X wrong!!!: x=272885.0, xmax=3840
# Y wrong!!!: y=14979.0, ymax=2748
# X wrong!!!: x=272206.0, xmax=3840
# Y wrong!!!: y=15145.0, ymax=2748
# X wrong!!!: x=271492.0, xmax=3840
# Y wrong!!!: y=15288.0, ymax=2748
# X wrong!!!: x=270749.0, xmax=3840
# Y wrong!!!: y=15407.0, ymax=2748
# X wrong!!!: x=269981.0, xmax=3840
# Y wrong!!!: y=15500.0, ymax=2748
# X wrong!!!: x=269195.0, xmax=3840
# Y wrong!!!: y=15567.0, ymax=2748
# X wrong!!!: x=268397.0, xmax=3840
# Y wrong!!!: y=15607.0, ymax=2748
# X wrong!!!: x=267593.0, xmax=3840
# Y wrong!!!: y=15621.0, ymax=2748
# X wrong!!!: x=266789.0, xmax=3840
# Y wrong!!!: y=15607.0, ymax=2748
# X wrong!!!: x=265991.0, xmax=3840
# Y wrong!!!: y=15567.0, ymax=2748
# X wrong!!!: x=265205.0, xmax=3840
# Y wrong!!!: y=15500.0, ymax=2748
# X wrong!!!: x=264437.0, xmax=3840
# Y wrong!!!: y=15407.0, ymax=2748
# X wrong!!!: x=263694.0, xmax=3840
# Y wrong!!!: y=15288.0, ymax=2748
# X wrong!!!: x=262980.0, xmax=3840
# Y wrong!!!: y=15145.0, ymax=2748
# X wrong!!!: x=262301.0, xmax=3840
# Y wrong!!!: y=14979.0, ymax=2748
# X wrong!!!: x=261662.0, xmax=3840
# Y wrong!!!: y=14790.0, ymax=2748
# X wrong!!!: x=261069.0, xmax=3840
# Y wrong!!!: y=14581.0, ymax=2748
# X wrong!!!: x=260525.0, xmax=3840
# Y wrong!!!: y=14353.0, ymax=2748
# X wrong!!!: x=260035.0, xmax=3840
# Y wrong!!!: y=14107.0, ymax=2748
# X wrong!!!: x=259602.0, xmax=3840
# Y wrong!!!: y=13846.0, ymax=2748
# X wrong!!!: x=259230.0, xmax=3840
# Y wrong!!!: y=13571.0, ymax=2748
# X wrong!!!: x=258922.0, xmax=3840
# Y wrong!!!: y=13285.0, ymax=2748
# X wrong!!!: x=258680.0, xmax=3840
# Y wrong!!!: y=12990.0, ymax=2748
# X wrong!!!: x=258506.0, xmax=3840
# Y wrong!!!: y=12687.0, ymax=2748
# X wrong!!!: x=258401.0, xmax=3840
# Y wrong!!!: y=12380.0, ymax=2748
# X wrong!!!: x=258366.0, xmax=3840
# Y wrong!!!: y=12071.0, ymax=2748
# X wrong!!!: x=258401.0, xmax=3840
# Y wrong!!!: y=11762.0, ymax=2748
# X wrong!!!: x=258506.0, xmax=3840
# Y wrong!!!: y=11455.0, ymax=2748
# X wrong!!!: x=258680.0, xmax=3840
# Y wrong!!!: y=11152.0, ymax=2748
# X wrong!!!: x=258922.0, xmax=3840
# Y wrong!!!: y=10857.0, ymax=2748
# X wrong!!!: x=259230.0, xmax=3840
# Y wrong!!!: y=10571.0, ymax=2748
# X wrong!!!: x=259602.0, xmax=3840
# Y wrong!!!: y=10296.0, ymax=2748
# X wrong!!!: x=260035.0, xmax=3840
# Y wrong!!!: y=10035.0, ymax=2748
# X wrong!!!: x=260525.0, xmax=3840
# Y wrong!!!: y=9789.0, ymax=2748
# X wrong!!!: x=261069.0, xmax=3840
# Y wrong!!!: y=9561.0, ymax=2748
# X wrong!!!: x=261662.0, xmax=3840
# Y wrong!!!: y=9352.0, ymax=2748
# X wrong!!!: x=262301.0, xmax=3840
# Y wrong!!!: y=9163.0, ymax=2748
# X wrong!!!: x=262980.0, xmax=3840
# Y wrong!!!: y=8997.0, ymax=2748
# X wrong!!!: x=263694.0, xmax=3840
# Y wrong!!!: y=8854.0, ymax=2748
# X wrong!!!: x=264437.0, xmax=3840
# Y wrong!!!: y=8735.0, ymax=2748
# X wrong!!!: x=265205.0, xmax=3840
# Y wrong!!!: y=8642.0, ymax=2748
# X wrong!!!: x=265991.0, xmax=3840
# Y wrong!!!: y=8575.0, ymax=2748
# X wrong!!!: x=266789.0, xmax=3840
# Y wrong!!!: y=8535.0, ymax=2748
# X wrong!!!: x=267593.0, xmax=3840
# Y wrong!!!: y=8521.0, ymax=2748
# X wrong!!!: x=268397.0, xmax=3840
# Y wrong!!!: y=8535.0, ymax=2748
# X wrong!!!: x=269195.0, xmax=3840
# Y wrong!!!: y=8575.0, ymax=2748
# X wrong!!!: x=269981.0, xmax=3840
# Y wrong!!!: y=8642.0, ymax=2748
# X wrong!!!: x=270749.0, xmax=3840
# Y wrong!!!: y=8735.0, ymax=2748
# X wrong!!!: x=271492.0, xmax=3840
# Y wrong!!!: y=8854.0, ymax=2748
# X wrong!!!: x=272206.0, xmax=3840
# Y wrong!!!: y=8997.0, ymax=2748
# X wrong!!!: x=272885.0, xmax=3840
# Y wrong!!!: y=9163.0, ymax=2748
# X wrong!!!: x=273524.0, xmax=3840
# Y wrong!!!: y=9352.0, ymax=2748
# X wrong!!!: x=274117.0, xmax=3840
# Y wrong!!!: y=9561.0, ymax=2748
# X wrong!!!: x=274661.0, xmax=3840
# Y wrong!!!: y=9789.0, ymax=2748
# X wrong!!!: x=275151.0, xmax=3840
# Y wrong!!!: y=10035.0, ymax=2748
# X wrong!!!: x=275584.0, xmax=3840
# Y wrong!!!: y=10296.0, ymax=2748
# X wrong!!!: x=275956.0, xmax=3840
# Y wrong!!!: y=10571.0, ymax=2748
# X wrong!!!: x=276264.0, xmax=3840
# Y wrong!!!: y=10857.0, ymax=2748
# X wrong!!!: x=276506.0, xmax=3840
# Y wrong!!!: y=11152.0, ymax=2748
# X wrong!!!: x=276680.0, xmax=3840
# Y wrong!!!: y=11455.0, ymax=2748
# X wrong!!!: x=276785.0, xmax=3840
# Y wrong!!!: y=11762.0, ymax=2748
# X wrong!!!: x=276820.0, xmax=3840
# Y wrong!!!: y=12071.0, ymax=2748
# X wrong!!!: x=319407.0, xmax=3840
# Y wrong!!!: y=17041.0, ymax=2748
# X wrong!!!: x=319364.0, xmax=3840
# Y wrong!!!: y=17412.0, ymax=2748
# X wrong!!!: x=319234.0, xmax=3840
# Y wrong!!!: y=17781.0, ymax=2748
# X wrong!!!: x=319020.0, xmax=3840
# Y wrong!!!: y=18144.0, ymax=2748
# X wrong!!!: x=318722.0, xmax=3840
# Y wrong!!!: y=18498.0, ymax=2748
# X wrong!!!: x=318343.0, xmax=3840
# Y wrong!!!: y=18841.0, ymax=2748
# X wrong!!!: x=317886.0, xmax=3840
# Y wrong!!!: y=19171.0, ymax=2748
# X wrong!!!: x=317353.0, xmax=3840
# Y wrong!!!: y=19484.0, ymax=2748
# X wrong!!!: x=316750.0, xmax=3840
# Y wrong!!!: y=19779.0, ymax=2748
# X wrong!!!: x=316081.0, xmax=3840
# Y wrong!!!: y=20053.0, ymax=2748
# X wrong!!!: x=315350.0, xmax=3840
# Y wrong!!!: y=20304.0, ymax=2748
# X wrong!!!: x=314565.0, xmax=3840
# Y wrong!!!: y=20531.0, ymax=2748
# X wrong!!!: x=313729.0, xmax=3840
# Y wrong!!!: y=20730.0, ymax=2748
# X wrong!!!: x=312850.0, xmax=3840
# Y wrong!!!: y=20902.0, ymax=2748
# X wrong!!!: x=311935.0, xmax=3840
# Y wrong!!!: y=21044.0, ymax=2748
# X wrong!!!: x=310990.0, xmax=3840
# Y wrong!!!: y=21156.0, ymax=2748
# X wrong!!!: x=310023.0, xmax=3840
# Y wrong!!!: y=21236.0, ymax=2748
# X wrong!!!: x=309041.0, xmax=3840
# Y wrong!!!: y=21285.0, ymax=2748
# X wrong!!!: x=308051.0, xmax=3840
# Y wrong!!!: y=21301.0, ymax=2748
# X wrong!!!: x=307061.0, xmax=3840
# Y wrong!!!: y=21285.0, ymax=2748
# X wrong!!!: x=306079.0, xmax=3840
# Y wrong!!!: y=21236.0, ymax=2748
# X wrong!!!: x=305112.0, xmax=3840
# Y wrong!!!: y=21156.0, ymax=2748
# X wrong!!!: x=304167.0, xmax=3840
# Y wrong!!!: y=21044.0, ymax=2748
# X wrong!!!: x=303252.0, xmax=3840
# Y wrong!!!: y=20902.0, ymax=2748
# X wrong!!!: x=302373.0, xmax=3840
# Y wrong!!!: y=20730.0, ymax=2748
# X wrong!!!: x=301537.0, xmax=3840
# Y wrong!!!: y=20531.0, ymax=2748
# X wrong!!!: x=300752.0, xmax=3840
# Y wrong!!!: y=20304.0, ymax=2748
# X wrong!!!: x=300021.0, xmax=3840
# Y wrong!!!: y=20053.0, ymax=2748
# X wrong!!!: x=299352.0, xmax=3840
# Y wrong!!!: y=19779.0, ymax=2748
# X wrong!!!: x=298749.0, xmax=3840
# Y wrong!!!: y=19484.0, ymax=2748
# X wrong!!!: x=298216.0, xmax=3840
# Y wrong!!!: y=19171.0, ymax=2748
# X wrong!!!: x=297759.0, xmax=3840
# Y wrong!!!: y=18841.0, ymax=2748
# X wrong!!!: x=297380.0, xmax=3840
# Y wrong!!!: y=18498.0, ymax=2748
# X wrong!!!: x=297082.0, xmax=3840
# Y wrong!!!: y=18144.0, ymax=2748
# X wrong!!!: x=296868.0, xmax=3840
# Y wrong!!!: y=17781.0, ymax=2748
# X wrong!!!: x=296738.0, xmax=3840
# Y wrong!!!: y=17412.0, ymax=2748
# X wrong!!!: x=296695.0, xmax=3840
# Y wrong!!!: y=17041.0, ymax=2748
# X wrong!!!: x=296738.0, xmax=3840
# Y wrong!!!: y=16670.0, ymax=2748
# X wrong!!!: x=296868.0, xmax=3840
# Y wrong!!!: y=16301.0, ymax=2748
# X wrong!!!: x=297082.0, xmax=3840
# Y wrong!!!: y=15938.0, ymax=2748
# X wrong!!!: x=297380.0, xmax=3840
# Y wrong!!!: y=15584.0, ymax=2748
# X wrong!!!: x=297759.0, xmax=3840
# Y wrong!!!: y=15241.0, ymax=2748
# X wrong!!!: x=298216.0, xmax=3840
# Y wrong!!!: y=14911.0, ymax=2748
# X wrong!!!: x=298749.0, xmax=3840
# Y wrong!!!: y=14598.0, ymax=2748
# X wrong!!!: x=299352.0, xmax=3840
# Y wrong!!!: y=14303.0, ymax=2748
# X wrong!!!: x=300021.0, xmax=3840
# Y wrong!!!: y=14029.0, ymax=2748
# X wrong!!!: x=300752.0, xmax=3840
# Y wrong!!!: y=13778.0, ymax=2748
# X wrong!!!: x=301537.0, xmax=3840
# Y wrong!!!: y=13551.0, ymax=2748
# X wrong!!!: x=302373.0, xmax=3840
# Y wrong!!!: y=13352.0, ymax=2748
# X wrong!!!: x=303252.0, xmax=3840
# Y wrong!!!: y=13180.0, ymax=2748
# X wrong!!!: x=304167.0, xmax=3840
# Y wrong!!!: y=13038.0, ymax=2748
# X wrong!!!: x=305112.0, xmax=3840
# Y wrong!!!: y=12926.0, ymax=2748
# X wrong!!!: x=306079.0, xmax=3840
# Y wrong!!!: y=12846.0, ymax=2748
# X wrong!!!: x=307061.0, xmax=3840
# Y wrong!!!: y=12797.0, ymax=2748
# X wrong!!!: x=308051.0, xmax=3840
# Y wrong!!!: y=12781.0, ymax=2748
# X wrong!!!: x=309041.0, xmax=3840
# Y wrong!!!: y=12797.0, ymax=2748
# X wrong!!!: x=310023.0, xmax=3840
# Y wrong!!!: y=12846.0, ymax=2748
# X wrong!!!: x=310990.0, xmax=3840
# Y wrong!!!: y=12926.0, ymax=2748
# X wrong!!!: x=311935.0, xmax=3840
# Y wrong!!!: y=13038.0, ymax=2748
# X wrong!!!: x=312850.0, xmax=3840
# Y wrong!!!: y=13180.0, ymax=2748
# X wrong!!!: x=313729.0, xmax=3840
# Y wrong!!!: y=13352.0, ymax=2748
# X wrong!!!: x=314565.0, xmax=3840
# Y wrong!!!: y=13551.0, ymax=2748
# X wrong!!!: x=315350.0, xmax=3840
# Y wrong!!!: y=13778.0, ymax=2748
# X wrong!!!: x=316081.0, xmax=3840
# Y wrong!!!: y=14029.0, ymax=2748
# X wrong!!!: x=316750.0, xmax=3840
# Y wrong!!!: y=14303.0, ymax=2748
# X wrong!!!: x=317353.0, xmax=3840
# Y wrong!!!: y=14598.0, ymax=2748
# X wrong!!!: x=317886.0, xmax=3840
# Y wrong!!!: y=14911.0, ymax=2748
# X wrong!!!: x=318343.0, xmax=3840
# Y wrong!!!: y=15241.0, ymax=2748
# X wrong!!!: x=318722.0, xmax=3840
# Y wrong!!!: y=15584.0, ymax=2748
# X wrong!!!: x=319020.0, xmax=3840
# Y wrong!!!: y=15938.0, ymax=2748
# X wrong!!!: x=319234.0, xmax=3840
# Y wrong!!!: y=16301.0, ymax=2748
# X wrong!!!: x=319364.0, xmax=3840
# Y wrong!!!: y=16670.0, ymax=2748
# X wrong!!!: x=319407.0, xmax=3840
# Y wrong!!!: y=17041.0, ymax=2748
# X wrong!!!: x=369093.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=369062.0, xmax=3840
# Y wrong!!!: y=25933.0, ymax=2748
# X wrong!!!: x=368969.0, xmax=3840
# Y wrong!!!: y=26302.0, ymax=2748
# X wrong!!!: x=368815.0, xmax=3840
# Y wrong!!!: y=26665.0, ymax=2748
# X wrong!!!: x=368601.0, xmax=3840
# Y wrong!!!: y=27019.0, ymax=2748
# X wrong!!!: x=368328.0, xmax=3840
# Y wrong!!!: y=27362.0, ymax=2748
# X wrong!!!: x=367999.0, xmax=3840
# Y wrong!!!: y=27692.0, ymax=2748
# X wrong!!!: x=367617.0, xmax=3840
# Y wrong!!!: y=28005.0, ymax=2748
# X wrong!!!: x=367183.0, xmax=3840
# Y wrong!!!: y=28300.0, ymax=2748
# X wrong!!!: x=366702.0, xmax=3840
# Y wrong!!!: y=28574.0, ymax=2748
# X wrong!!!: x=366177.0, xmax=3840
# Y wrong!!!: y=28825.0, ymax=2748
# X wrong!!!: x=365613.0, xmax=3840
# Y wrong!!!: y=29052.0, ymax=2748
# X wrong!!!: x=365012.0, xmax=3840
# Y wrong!!!: y=29251.0, ymax=2748
# X wrong!!!: x=364380.0, xmax=3840
# Y wrong!!!: y=29423.0, ymax=2748
# X wrong!!!: x=363723.0, xmax=3840
# Y wrong!!!: y=29565.0, ymax=2748
# X wrong!!!: x=363043.0, xmax=3840
# Y wrong!!!: y=29677.0, ymax=2748
# X wrong!!!: x=362348.0, xmax=3840
# Y wrong!!!: y=29757.0, ymax=2748
# X wrong!!!: x=361642.0, xmax=3840
# Y wrong!!!: y=29806.0, ymax=2748
# X wrong!!!: x=360931.0, xmax=3840
# Y wrong!!!: y=29822.0, ymax=2748
# X wrong!!!: x=360220.0, xmax=3840
# Y wrong!!!: y=29806.0, ymax=2748
# X wrong!!!: x=359514.0, xmax=3840
# Y wrong!!!: y=29757.0, ymax=2748
# X wrong!!!: x=358819.0, xmax=3840
# Y wrong!!!: y=29677.0, ymax=2748
# X wrong!!!: x=358139.0, xmax=3840
# Y wrong!!!: y=29565.0, ymax=2748
# X wrong!!!: x=357482.0, xmax=3840
# Y wrong!!!: y=29423.0, ymax=2748
# X wrong!!!: x=356850.0, xmax=3840
# Y wrong!!!: y=29251.0, ymax=2748
# X wrong!!!: x=356249.0, xmax=3840
# Y wrong!!!: y=29052.0, ymax=2748
# X wrong!!!: x=355685.0, xmax=3840
# Y wrong!!!: y=28825.0, ymax=2748
# X wrong!!!: x=355160.0, xmax=3840
# Y wrong!!!: y=28574.0, ymax=2748
# X wrong!!!: x=354679.0, xmax=3840
# Y wrong!!!: y=28300.0, ymax=2748
# X wrong!!!: x=354245.0, xmax=3840
# Y wrong!!!: y=28005.0, ymax=2748
# X wrong!!!: x=353863.0, xmax=3840
# Y wrong!!!: y=27692.0, ymax=2748
# X wrong!!!: x=353534.0, xmax=3840
# Y wrong!!!: y=27362.0, ymax=2748
# X wrong!!!: x=353261.0, xmax=3840
# Y wrong!!!: y=27019.0, ymax=2748
# X wrong!!!: x=353047.0, xmax=3840
# Y wrong!!!: y=26665.0, ymax=2748
# X wrong!!!: x=352893.0, xmax=3840
# Y wrong!!!: y=26302.0, ymax=2748
# X wrong!!!: x=352800.0, xmax=3840
# Y wrong!!!: y=25933.0, ymax=2748
# X wrong!!!: x=352769.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=352800.0, xmax=3840
# Y wrong!!!: y=25191.0, ymax=2748
# X wrong!!!: x=352893.0, xmax=3840
# Y wrong!!!: y=24822.0, ymax=2748
# X wrong!!!: x=353047.0, xmax=3840
# Y wrong!!!: y=24459.0, ymax=2748
# X wrong!!!: x=353261.0, xmax=3840
# Y wrong!!!: y=24105.0, ymax=2748
# X wrong!!!: x=353534.0, xmax=3840
# Y wrong!!!: y=23762.0, ymax=2748
# X wrong!!!: x=353863.0, xmax=3840
# Y wrong!!!: y=23432.0, ymax=2748
# X wrong!!!: x=354245.0, xmax=3840
# Y wrong!!!: y=23119.0, ymax=2748
# X wrong!!!: x=354679.0, xmax=3840
# Y wrong!!!: y=22824.0, ymax=2748
# X wrong!!!: x=355160.0, xmax=3840
# Y wrong!!!: y=22550.0, ymax=2748
# X wrong!!!: x=355685.0, xmax=3840
# Y wrong!!!: y=22299.0, ymax=2748
# X wrong!!!: x=356249.0, xmax=3840
# Y wrong!!!: y=22072.0, ymax=2748
# X wrong!!!: x=356850.0, xmax=3840
# Y wrong!!!: y=21873.0, ymax=2748
# X wrong!!!: x=357482.0, xmax=3840
# Y wrong!!!: y=21701.0, ymax=2748
# X wrong!!!: x=358139.0, xmax=3840
# Y wrong!!!: y=21559.0, ymax=2748
# X wrong!!!: x=358819.0, xmax=3840
# Y wrong!!!: y=21447.0, ymax=2748
# X wrong!!!: x=359514.0, xmax=3840
# Y wrong!!!: y=21367.0, ymax=2748
# X wrong!!!: x=360220.0, xmax=3840
# Y wrong!!!: y=21318.0, ymax=2748
# X wrong!!!: x=360931.0, xmax=3840
# Y wrong!!!: y=21302.0, ymax=2748
# X wrong!!!: x=361642.0, xmax=3840
# Y wrong!!!: y=21318.0, ymax=2748
# X wrong!!!: x=362348.0, xmax=3840
# Y wrong!!!: y=21367.0, ymax=2748
# X wrong!!!: x=363043.0, xmax=3840
# Y wrong!!!: y=21447.0, ymax=2748
# X wrong!!!: x=363723.0, xmax=3840
# Y wrong!!!: y=21559.0, ymax=2748
# X wrong!!!: x=364380.0, xmax=3840
# Y wrong!!!: y=21701.0, ymax=2748
# X wrong!!!: x=365012.0, xmax=3840
# Y wrong!!!: y=21873.0, ymax=2748
# X wrong!!!: x=365613.0, xmax=3840
# Y wrong!!!: y=22072.0, ymax=2748
# X wrong!!!: x=366177.0, xmax=3840
# Y wrong!!!: y=22299.0, ymax=2748
# X wrong!!!: x=366702.0, xmax=3840
# Y wrong!!!: y=22550.0, ymax=2748
# X wrong!!!: x=367183.0, xmax=3840
# Y wrong!!!: y=22824.0, ymax=2748
# X wrong!!!: x=367617.0, xmax=3840
# Y wrong!!!: y=23119.0, ymax=2748
# X wrong!!!: x=367999.0, xmax=3840
# Y wrong!!!: y=23432.0, ymax=2748
# X wrong!!!: x=368328.0, xmax=3840
# Y wrong!!!: y=23762.0, ymax=2748
# X wrong!!!: x=368601.0, xmax=3840
# Y wrong!!!: y=24105.0, ymax=2748
# X wrong!!!: x=368815.0, xmax=3840
# Y wrong!!!: y=24459.0, ymax=2748
# X wrong!!!: x=368969.0, xmax=3840
# Y wrong!!!: y=24822.0, ymax=2748
# X wrong!!!: x=369062.0, xmax=3840
# Y wrong!!!: y=25191.0, ymax=2748
# X wrong!!!: x=369093.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=21292.0, xmax=3840
# Y wrong!!!: y=19172.0, ymax=2748
# X wrong!!!: x=21265.0, xmax=3840
# Y wrong!!!: y=19729.0, ymax=2748
# X wrong!!!: x=21184.0, xmax=3840
# Y wrong!!!: y=20282.0, ymax=2748
# X wrong!!!: x=21050.0, xmax=3840
# Y wrong!!!: y=20826.0, ymax=2748
# X wrong!!!: x=20864.0, xmax=3840
# Y wrong!!!: y=21358.0, ymax=2748
# X wrong!!!: x=20627.0, xmax=3840
# Y wrong!!!: y=21873.0, ymax=2748
# X wrong!!!: x=20341.0, xmax=3840
# Y wrong!!!: y=22367.0, ymax=2748
# X wrong!!!: x=20009.0, xmax=3840
# Y wrong!!!: y=22837.0, ymax=2748
# X wrong!!!: x=19632.0, xmax=3840
# Y wrong!!!: y=23279.0, ymax=2748
# X wrong!!!: x=19213.0, xmax=3840
# Y wrong!!!: y=23690.0, ymax=2748
# X wrong!!!: x=18757.0, xmax=3840
# Y wrong!!!: y=24067.0, ymax=2748
# X wrong!!!: x=18266.0, xmax=3840
# Y wrong!!!: y=24406.0, ymax=2748
# X wrong!!!: x=17744.0, xmax=3840
# Y wrong!!!: y=24706.0, ymax=2748
# X wrong!!!: x=17194.0, xmax=3840
# Y wrong!!!: y=24963.0, ymax=2748
# X wrong!!!: x=16622.0, xmax=3840
# Y wrong!!!: y=25177.0, ymax=2748
# X wrong!!!: x=16032.0, xmax=3840
# Y wrong!!!: y=25344.0, ymax=2748
# X wrong!!!: x=15427.0, xmax=3840
# Y wrong!!!: y=25465.0, ymax=2748
# X wrong!!!: x=14814.0, xmax=3840
# Y wrong!!!: y=25538.0, ymax=2748
# X wrong!!!: x=14195.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=13576.0, xmax=3840
# Y wrong!!!: y=25538.0, ymax=2748
# X wrong!!!: x=12963.0, xmax=3840
# Y wrong!!!: y=25465.0, ymax=2748
# X wrong!!!: x=12358.0, xmax=3840
# Y wrong!!!: y=25344.0, ymax=2748
# X wrong!!!: x=11768.0, xmax=3840
# Y wrong!!!: y=25177.0, ymax=2748
# X wrong!!!: x=11196.0, xmax=3840
# Y wrong!!!: y=24963.0, ymax=2748
# X wrong!!!: x=10646.0, xmax=3840
# Y wrong!!!: y=24706.0, ymax=2748
# X wrong!!!: x=10124.0, xmax=3840
# Y wrong!!!: y=24406.0, ymax=2748
# X wrong!!!: x=9633.0, xmax=3840
# Y wrong!!!: y=24067.0, ymax=2748
# X wrong!!!: x=9177.0, xmax=3840
# Y wrong!!!: y=23690.0, ymax=2748
# X wrong!!!: x=8758.0, xmax=3840
# Y wrong!!!: y=23279.0, ymax=2748
# X wrong!!!: x=8381.0, xmax=3840
# Y wrong!!!: y=22837.0, ymax=2748
# X wrong!!!: x=8049.0, xmax=3840
# Y wrong!!!: y=22367.0, ymax=2748
# X wrong!!!: x=7763.0, xmax=3840
# Y wrong!!!: y=21873.0, ymax=2748
# X wrong!!!: x=7526.0, xmax=3840
# Y wrong!!!: y=21358.0, ymax=2748
# X wrong!!!: x=7340.0, xmax=3840
# Y wrong!!!: y=20826.0, ymax=2748
# X wrong!!!: x=7206.0, xmax=3840
# Y wrong!!!: y=20282.0, ymax=2748
# X wrong!!!: x=7125.0, xmax=3840
# Y wrong!!!: y=19729.0, ymax=2748
# X wrong!!!: x=7098.0, xmax=3840
# Y wrong!!!: y=19172.0, ymax=2748
# X wrong!!!: x=7125.0, xmax=3840
# Y wrong!!!: y=18615.0, ymax=2748
# X wrong!!!: x=7206.0, xmax=3840
# Y wrong!!!: y=18062.0, ymax=2748
# X wrong!!!: x=7340.0, xmax=3840
# Y wrong!!!: y=17518.0, ymax=2748
# X wrong!!!: x=7526.0, xmax=3840
# Y wrong!!!: y=16986.0, ymax=2748
# X wrong!!!: x=7763.0, xmax=3840
# Y wrong!!!: y=16471.0, ymax=2748
# X wrong!!!: x=8049.0, xmax=3840
# Y wrong!!!: y=15977.0, ymax=2748
# X wrong!!!: x=8381.0, xmax=3840
# Y wrong!!!: y=15507.0, ymax=2748
# X wrong!!!: x=8758.0, xmax=3840
# Y wrong!!!: y=15065.0, ymax=2748
# X wrong!!!: x=9177.0, xmax=3840
# Y wrong!!!: y=14654.0, ymax=2748
# X wrong!!!: x=9633.0, xmax=3840
# Y wrong!!!: y=14277.0, ymax=2748
# X wrong!!!: x=10124.0, xmax=3840
# Y wrong!!!: y=13938.0, ymax=2748
# X wrong!!!: x=10646.0, xmax=3840
# Y wrong!!!: y=13638.0, ymax=2748
# X wrong!!!: x=11196.0, xmax=3840
# Y wrong!!!: y=13381.0, ymax=2748
# X wrong!!!: x=11768.0, xmax=3840
# Y wrong!!!: y=13167.0, ymax=2748
# X wrong!!!: x=12358.0, xmax=3840
# Y wrong!!!: y=13000.0, ymax=2748
# X wrong!!!: x=12963.0, xmax=3840
# Y wrong!!!: y=12879.0, ymax=2748
# X wrong!!!: x=13576.0, xmax=3840
# Y wrong!!!: y=12806.0, ymax=2748
# X wrong!!!: x=14195.0, xmax=3840
# Y wrong!!!: y=12782.0, ymax=2748
# X wrong!!!: x=14814.0, xmax=3840
# Y wrong!!!: y=12806.0, ymax=2748
# X wrong!!!: x=15427.0, xmax=3840
# Y wrong!!!: y=12879.0, ymax=2748
# X wrong!!!: x=16032.0, xmax=3840
# Y wrong!!!: y=13000.0, ymax=2748
# X wrong!!!: x=16622.0, xmax=3840
# Y wrong!!!: y=13167.0, ymax=2748
# X wrong!!!: x=17194.0, xmax=3840
# Y wrong!!!: y=13381.0, ymax=2748
# X wrong!!!: x=17744.0, xmax=3840
# Y wrong!!!: y=13638.0, ymax=2748
# X wrong!!!: x=18266.0, xmax=3840
# Y wrong!!!: y=13938.0, ymax=2748
# X wrong!!!: x=18757.0, xmax=3840
# Y wrong!!!: y=14277.0, ymax=2748
# X wrong!!!: x=19213.0, xmax=3840
# Y wrong!!!: y=14654.0, ymax=2748
# X wrong!!!: x=19632.0, xmax=3840
# Y wrong!!!: y=15065.0, ymax=2748
# X wrong!!!: x=20009.0, xmax=3840
# Y wrong!!!: y=15507.0, ymax=2748
# X wrong!!!: x=20341.0, xmax=3840
# Y wrong!!!: y=15977.0, ymax=2748
# X wrong!!!: x=20627.0, xmax=3840
# Y wrong!!!: y=16471.0, ymax=2748
# X wrong!!!: x=20864.0, xmax=3840
# Y wrong!!!: y=16986.0, ymax=2748
# X wrong!!!: x=21050.0, xmax=3840
# Y wrong!!!: y=17518.0, ymax=2748
# X wrong!!!: x=21184.0, xmax=3840
# Y wrong!!!: y=18062.0, ymax=2748
# X wrong!!!: x=21265.0, xmax=3840
# Y wrong!!!: y=18615.0, ymax=2748
# X wrong!!!: x=21292.0, xmax=3840
# Y wrong!!!: y=19172.0, ymax=2748
# X wrong!!!: x=53233.0, xmax=3840
# Y wrong!!!: y=22722.0, ymax=2748
# X wrong!!!: x=53203.0, xmax=3840
# Y wrong!!!: y=23465.0, ymax=2748
# X wrong!!!: x=53114.0, xmax=3840
# Y wrong!!!: y=24201.0, ymax=2748
# X wrong!!!: x=52967.0, xmax=3840
# Y wrong!!!: y=24927.0, ymax=2748
# X wrong!!!: x=52762.0, xmax=3840
# Y wrong!!!: y=25636.0, ymax=2748
# X wrong!!!: x=52502.0, xmax=3840
# Y wrong!!!: y=26323.0, ymax=2748
# X wrong!!!: x=52187.0, xmax=3840
# Y wrong!!!: y=26982.0, ymax=2748
# X wrong!!!: x=51821.0, xmax=3840
# Y wrong!!!: y=27609.0, ymax=2748
# X wrong!!!: x=51407.0, xmax=3840
# Y wrong!!!: y=28199.0, ymax=2748
# X wrong!!!: x=50946.0, xmax=3840
# Y wrong!!!: y=28747.0, ymax=2748
# X wrong!!!: x=50444.0, xmax=3840
# Y wrong!!!: y=29249.0, ymax=2748
# X wrong!!!: x=49904.0, xmax=3840
# Y wrong!!!: y=29701.0, ymax=2748
# X wrong!!!: x=49330.0, xmax=3840
# Y wrong!!!: y=30101.0, ymax=2748
# X wrong!!!: x=48725.0, xmax=3840
# Y wrong!!!: y=30444.0, ymax=2748
# X wrong!!!: x=48096.0, xmax=3840
# Y wrong!!!: y=30728.0, ymax=2748
# X wrong!!!: x=47447.0, xmax=3840
# Y wrong!!!: y=30952.0, ymax=2748
# X wrong!!!: x=46782.0, xmax=3840
# Y wrong!!!: y=31113.0, ymax=2748
# X wrong!!!: x=46106.0, xmax=3840
# Y wrong!!!: y=31210.0, ymax=2748
# X wrong!!!: x=45426.0, xmax=3840
# Y wrong!!!: y=31242.0, ymax=2748
# X wrong!!!: x=44746.0, xmax=3840
# Y wrong!!!: y=31210.0, ymax=2748
# X wrong!!!: x=44070.0, xmax=3840
# Y wrong!!!: y=31113.0, ymax=2748
# X wrong!!!: x=43405.0, xmax=3840
# Y wrong!!!: y=30952.0, ymax=2748
# X wrong!!!: x=42756.0, xmax=3840
# Y wrong!!!: y=30728.0, ymax=2748
# X wrong!!!: x=42127.0, xmax=3840
# Y wrong!!!: y=30444.0, ymax=2748
# X wrong!!!: x=41522.0, xmax=3840
# Y wrong!!!: y=30101.0, ymax=2748
# X wrong!!!: x=40948.0, xmax=3840
# Y wrong!!!: y=29701.0, ymax=2748
# X wrong!!!: x=40408.0, xmax=3840
# Y wrong!!!: y=29249.0, ymax=2748
# X wrong!!!: x=39906.0, xmax=3840
# Y wrong!!!: y=28747.0, ymax=2748
# X wrong!!!: x=39445.0, xmax=3840
# Y wrong!!!: y=28199.0, ymax=2748
# X wrong!!!: x=39031.0, xmax=3840
# Y wrong!!!: y=27609.0, ymax=2748
# X wrong!!!: x=38665.0, xmax=3840
# Y wrong!!!: y=26982.0, ymax=2748
# X wrong!!!: x=38350.0, xmax=3840
# Y wrong!!!: y=26323.0, ymax=2748
# X wrong!!!: x=38090.0, xmax=3840
# Y wrong!!!: y=25636.0, ymax=2748
# X wrong!!!: x=37885.0, xmax=3840
# Y wrong!!!: y=24927.0, ymax=2748
# X wrong!!!: x=37738.0, xmax=3840
# Y wrong!!!: y=24201.0, ymax=2748
# X wrong!!!: x=37649.0, xmax=3840
# Y wrong!!!: y=23465.0, ymax=2748
# X wrong!!!: x=37619.0, xmax=3840
# Y wrong!!!: y=22722.0, ymax=2748
# X wrong!!!: x=37649.0, xmax=3840
# Y wrong!!!: y=21979.0, ymax=2748
# X wrong!!!: x=37738.0, xmax=3840
# Y wrong!!!: y=21243.0, ymax=2748
# X wrong!!!: x=37885.0, xmax=3840
# Y wrong!!!: y=20517.0, ymax=2748
# X wrong!!!: x=38090.0, xmax=3840
# Y wrong!!!: y=19808.0, ymax=2748
# X wrong!!!: x=38350.0, xmax=3840
# Y wrong!!!: y=19121.0, ymax=2748
# X wrong!!!: x=38665.0, xmax=3840
# Y wrong!!!: y=18462.0, ymax=2748
# X wrong!!!: x=39031.0, xmax=3840
# Y wrong!!!: y=17835.0, ymax=2748
# X wrong!!!: x=39445.0, xmax=3840
# Y wrong!!!: y=17245.0, ymax=2748
# X wrong!!!: x=39906.0, xmax=3840
# Y wrong!!!: y=16697.0, ymax=2748
# X wrong!!!: x=40408.0, xmax=3840
# Y wrong!!!: y=16195.0, ymax=2748
# X wrong!!!: x=40948.0, xmax=3840
# Y wrong!!!: y=15743.0, ymax=2748
# X wrong!!!: x=41522.0, xmax=3840
# Y wrong!!!: y=15343.0, ymax=2748
# X wrong!!!: x=42127.0, xmax=3840
# Y wrong!!!: y=15000.0, ymax=2748
# X wrong!!!: x=42756.0, xmax=3840
# Y wrong!!!: y=14716.0, ymax=2748
# X wrong!!!: x=43405.0, xmax=3840
# Y wrong!!!: y=14492.0, ymax=2748
# X wrong!!!: x=44070.0, xmax=3840
# Y wrong!!!: y=14331.0, ymax=2748
# X wrong!!!: x=44746.0, xmax=3840
# Y wrong!!!: y=14234.0, ymax=2748
# X wrong!!!: x=45426.0, xmax=3840
# Y wrong!!!: y=14202.0, ymax=2748
# X wrong!!!: x=46106.0, xmax=3840
# Y wrong!!!: y=14234.0, ymax=2748
# X wrong!!!: x=46782.0, xmax=3840
# Y wrong!!!: y=14331.0, ymax=2748
# X wrong!!!: x=47447.0, xmax=3840
# Y wrong!!!: y=14492.0, ymax=2748
# X wrong!!!: x=48096.0, xmax=3840
# Y wrong!!!: y=14716.0, ymax=2748
# X wrong!!!: x=48725.0, xmax=3840
# Y wrong!!!: y=15000.0, ymax=2748
# X wrong!!!: x=49330.0, xmax=3840
# Y wrong!!!: y=15343.0, ymax=2748
# X wrong!!!: x=49904.0, xmax=3840
# Y wrong!!!: y=15743.0, ymax=2748
# X wrong!!!: x=50444.0, xmax=3840
# Y wrong!!!: y=16195.0, ymax=2748
# X wrong!!!: x=50946.0, xmax=3840
# Y wrong!!!: y=16697.0, ymax=2748
# X wrong!!!: x=51407.0, xmax=3840
# Y wrong!!!: y=17245.0, ymax=2748
# X wrong!!!: x=51821.0, xmax=3840
# Y wrong!!!: y=17835.0, ymax=2748
# X wrong!!!: x=52187.0, xmax=3840
# Y wrong!!!: y=18462.0, ymax=2748
# X wrong!!!: x=52502.0, xmax=3840
# Y wrong!!!: y=19121.0, ymax=2748
# X wrong!!!: x=52762.0, xmax=3840
# Y wrong!!!: y=19808.0, ymax=2748
# X wrong!!!: x=52967.0, xmax=3840
# Y wrong!!!: y=20517.0, ymax=2748
# X wrong!!!: x=53114.0, xmax=3840
# Y wrong!!!: y=21243.0, ymax=2748
# X wrong!!!: x=53203.0, xmax=3840
# Y wrong!!!: y=21979.0, ymax=2748
# X wrong!!!: x=53233.0, xmax=3840
# Y wrong!!!: y=22722.0, ymax=2748
# X wrong!!!: x=82336.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=82301.0, xmax=3840
# Y wrong!!!: y=26057.0, ymax=2748
# X wrong!!!: x=82196.0, xmax=3840
# Y wrong!!!: y=26548.0, ymax=2748
# X wrong!!!: x=82022.0, xmax=3840
# Y wrong!!!: y=27032.0, ymax=2748
# X wrong!!!: x=81780.0, xmax=3840
# Y wrong!!!: y=27505.0, ymax=2748
# X wrong!!!: x=81472.0, xmax=3840
# Y wrong!!!: y=27962.0, ymax=2748
# X wrong!!!: x=81100.0, xmax=3840
# Y wrong!!!: y=28402.0, ymax=2748
# X wrong!!!: x=80667.0, xmax=3840
# Y wrong!!!: y=28820.0, ymax=2748
# X wrong!!!: x=80177.0, xmax=3840
# Y wrong!!!: y=29213.0, ymax=2748
# X wrong!!!: x=79633.0, xmax=3840
# Y wrong!!!: y=29578.0, ymax=2748
# X wrong!!!: x=79040.0, xmax=3840
# Y wrong!!!: y=29913.0, ymax=2748
# X wrong!!!: x=78401.0, xmax=3840
# Y wrong!!!: y=30215.0, ymax=2748
# X wrong!!!: x=77722.0, xmax=3840
# Y wrong!!!: y=30481.0, ymax=2748
# X wrong!!!: x=77008.0, xmax=3840
# Y wrong!!!: y=30710.0, ymax=2748
# X wrong!!!: x=76265.0, xmax=3840
# Y wrong!!!: y=30899.0, ymax=2748
# X wrong!!!: x=75497.0, xmax=3840
# Y wrong!!!: y=31048.0, ymax=2748
# X wrong!!!: x=74711.0, xmax=3840
# Y wrong!!!: y=31156.0, ymax=2748
# X wrong!!!: x=73913.0, xmax=3840
# Y wrong!!!: y=31220.0, ymax=2748
# X wrong!!!: x=73109.0, xmax=3840
# Y wrong!!!: y=31242.0, ymax=2748
# X wrong!!!: x=72305.0, xmax=3840
# Y wrong!!!: y=31220.0, ymax=2748
# X wrong!!!: x=71507.0, xmax=3840
# Y wrong!!!: y=31156.0, ymax=2748
# X wrong!!!: x=70721.0, xmax=3840
# Y wrong!!!: y=31048.0, ymax=2748
# X wrong!!!: x=69953.0, xmax=3840
# Y wrong!!!: y=30899.0, ymax=2748
# X wrong!!!: x=69210.0, xmax=3840
# Y wrong!!!: y=30710.0, ymax=2748
# X wrong!!!: x=68496.0, xmax=3840
# Y wrong!!!: y=30481.0, ymax=2748
# X wrong!!!: x=67817.0, xmax=3840
# Y wrong!!!: y=30215.0, ymax=2748
# X wrong!!!: x=67178.0, xmax=3840
# Y wrong!!!: y=29913.0, ymax=2748
# X wrong!!!: x=66585.0, xmax=3840
# Y wrong!!!: y=29578.0, ymax=2748
# X wrong!!!: x=66041.0, xmax=3840
# Y wrong!!!: y=29213.0, ymax=2748
# X wrong!!!: x=65551.0, xmax=3840
# Y wrong!!!: y=28820.0, ymax=2748
# X wrong!!!: x=65118.0, xmax=3840
# Y wrong!!!: y=28402.0, ymax=2748
# X wrong!!!: x=64746.0, xmax=3840
# Y wrong!!!: y=27962.0, ymax=2748
# X wrong!!!: x=64438.0, xmax=3840
# Y wrong!!!: y=27505.0, ymax=2748
# X wrong!!!: x=64196.0, xmax=3840
# Y wrong!!!: y=27032.0, ymax=2748
# X wrong!!!: x=64022.0, xmax=3840
# Y wrong!!!: y=26548.0, ymax=2748
# X wrong!!!: x=63917.0, xmax=3840
# Y wrong!!!: y=26057.0, ymax=2748
# X wrong!!!: x=63882.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=63917.0, xmax=3840
# Y wrong!!!: y=25067.0, ymax=2748
# X wrong!!!: x=64022.0, xmax=3840
# Y wrong!!!: y=24576.0, ymax=2748
# X wrong!!!: x=64196.0, xmax=3840
# Y wrong!!!: y=24092.0, ymax=2748
# X wrong!!!: x=64438.0, xmax=3840
# Y wrong!!!: y=23619.0, ymax=2748
# X wrong!!!: x=64746.0, xmax=3840
# Y wrong!!!: y=23162.0, ymax=2748
# X wrong!!!: x=65118.0, xmax=3840
# Y wrong!!!: y=22722.0, ymax=2748
# X wrong!!!: x=65551.0, xmax=3840
# Y wrong!!!: y=22304.0, ymax=2748
# X wrong!!!: x=66041.0, xmax=3840
# Y wrong!!!: y=21911.0, ymax=2748
# X wrong!!!: x=66585.0, xmax=3840
# Y wrong!!!: y=21546.0, ymax=2748
# X wrong!!!: x=67178.0, xmax=3840
# Y wrong!!!: y=21211.0, ymax=2748
# X wrong!!!: x=67817.0, xmax=3840
# Y wrong!!!: y=20909.0, ymax=2748
# X wrong!!!: x=68496.0, xmax=3840
# Y wrong!!!: y=20643.0, ymax=2748
# X wrong!!!: x=69210.0, xmax=3840
# Y wrong!!!: y=20414.0, ymax=2748
# X wrong!!!: x=69953.0, xmax=3840
# Y wrong!!!: y=20225.0, ymax=2748
# X wrong!!!: x=70721.0, xmax=3840
# Y wrong!!!: y=20076.0, ymax=2748
# X wrong!!!: x=71507.0, xmax=3840
# Y wrong!!!: y=19968.0, ymax=2748
# X wrong!!!: x=72305.0, xmax=3840
# Y wrong!!!: y=19904.0, ymax=2748
# X wrong!!!: x=73109.0, xmax=3840
# Y wrong!!!: y=19882.0, ymax=2748
# X wrong!!!: x=73913.0, xmax=3840
# Y wrong!!!: y=19904.0, ymax=2748
# X wrong!!!: x=74711.0, xmax=3840
# Y wrong!!!: y=19968.0, ymax=2748
# X wrong!!!: x=75497.0, xmax=3840
# Y wrong!!!: y=20076.0, ymax=2748
# X wrong!!!: x=76265.0, xmax=3840
# Y wrong!!!: y=20225.0, ymax=2748
# X wrong!!!: x=77008.0, xmax=3840
# Y wrong!!!: y=20414.0, ymax=2748
# X wrong!!!: x=77722.0, xmax=3840
# Y wrong!!!: y=20643.0, ymax=2748
# X wrong!!!: x=78401.0, xmax=3840
# Y wrong!!!: y=20909.0, ymax=2748
# X wrong!!!: x=79040.0, xmax=3840
# Y wrong!!!: y=21211.0, ymax=2748
# X wrong!!!: x=79633.0, xmax=3840
# Y wrong!!!: y=21546.0, ymax=2748
# X wrong!!!: x=80177.0, xmax=3840
# Y wrong!!!: y=21911.0, ymax=2748
# X wrong!!!: x=80667.0, xmax=3840
# Y wrong!!!: y=22304.0, ymax=2748
# X wrong!!!: x=81100.0, xmax=3840
# Y wrong!!!: y=22722.0, ymax=2748
# X wrong!!!: x=81472.0, xmax=3840
# Y wrong!!!: y=23162.0, ymax=2748
# X wrong!!!: x=81780.0, xmax=3840
# Y wrong!!!: y=23619.0, ymax=2748
# X wrong!!!: x=82022.0, xmax=3840
# Y wrong!!!: y=24092.0, ymax=2748
# X wrong!!!: x=82196.0, xmax=3840
# Y wrong!!!: y=24576.0, ymax=2748
# X wrong!!!: x=82301.0, xmax=3840
# Y wrong!!!: y=25067.0, ymax=2748
# X wrong!!!: x=82336.0, xmax=3840
# Y wrong!!!: y=25562.0, ymax=2748
# X wrong!!!: x=110017.0, xmax=3840
# Y wrong!!!: y=31953.0, ymax=2748
# X wrong!!!: x=109990.0, xmax=3840
# Y wrong!!!: y=32324.0, ymax=2748
# X wrong!!!: x=109909.0, xmax=3840
# Y wrong!!!: y=32693.0, ymax=2748
# X wrong!!!: x=109775.0, xmax=3840
# Y wrong!!!: y=33056.0, ymax=2748
# X wrong!!!: x=109589.0, xmax=3840
# Y wrong!!!: y=33410.0, ymax=2748
# X wrong!!!: x=109352.0, xmax=3840
# Y wrong!!!: y=33753.0, ymax=2748
# X wrong!!!: x=109066.0, xmax=3840
# Y wrong!!!: y=34083.0, ymax=2748
# X wrong!!!: x=108734.0, xmax=3840
# Y wrong!!!: y=34396.0, ymax=2748
# X wrong!!!: x=108357.0, xmax=3840
# Y wrong!!!: y=34691.0, ymax=2748
# X wrong!!!: x=107938.0, xmax=3840
# Y wrong!!!: y=34965.0, ymax=2748
# X wrong!!!: x=107482.0, xmax=3840
# Y wrong!!!: y=35216.0, ymax=2748
# X wrong!!!: x=106991.0, xmax=3840
# Y wrong!!!: y=35443.0, ymax=2748
# X wrong!!!: x=106468.0, xmax=3840
# Y wrong!!!: y=35642.0, ymax=2748
# X wrong!!!: x=105919.0, xmax=3840
# Y wrong!!!: y=35814.0, ymax=2748
# X wrong!!!: x=105347.0, xmax=3840
# Y wrong!!!: y=35956.0, ymax=2748
# X wrong!!!: x=104757.0, xmax=3840
# Y wrong!!!: y=36068.0, ymax=2748
# X wrong!!!: x=104152.0, xmax=3840
# Y wrong!!!: y=36148.0, ymax=2748
# X wrong!!!: x=103539.0, xmax=3840
# Y wrong!!!: y=36197.0, ymax=2748
# X wrong!!!: x=102920.0, xmax=3840
# Y wrong!!!: y=36213.0, ymax=2748
# X wrong!!!: x=102301.0, xmax=3840
# Y wrong!!!: y=36197.0, ymax=2748
# X wrong!!!: x=101688.0, xmax=3840
# Y wrong!!!: y=36148.0, ymax=2748
# X wrong!!!: x=101083.0, xmax=3840
# Y wrong!!!: y=36068.0, ymax=2748
# X wrong!!!: x=100493.0, xmax=3840
# Y wrong!!!: y=35956.0, ymax=2748
# X wrong!!!: x=99921.0, xmax=3840
# Y wrong!!!: y=35814.0, ymax=2748
# X wrong!!!: x=99372.0, xmax=3840
# Y wrong!!!: y=35642.0, ymax=2748
# X wrong!!!: x=98849.0, xmax=3840
# Y wrong!!!: y=35443.0, ymax=2748
# X wrong!!!: x=98358.0, xmax=3840
# Y wrong!!!: y=35216.0, ymax=2748
# X wrong!!!: x=97902.0, xmax=3840
# Y wrong!!!: y=34965.0, ymax=2748
# X wrong!!!: x=97483.0, xmax=3840
# Y wrong!!!: y=34691.0, ymax=2748
# X wrong!!!: x=97106.0, xmax=3840
# Y wrong!!!: y=34396.0, ymax=2748
# X wrong!!!: x=96774.0, xmax=3840
# Y wrong!!!: y=34083.0, ymax=2748
# X wrong!!!: x=96488.0, xmax=3840
# Y wrong!!!: y=33753.0, ymax=2748
# X wrong!!!: x=96251.0, xmax=3840
# Y wrong!!!: y=33410.0, ymax=2748
# X wrong!!!: x=96065.0, xmax=3840
# Y wrong!!!: y=33056.0, ymax=2748
# X wrong!!!: x=95931.0, xmax=3840
# Y wrong!!!: y=32693.0, ymax=2748
# X wrong!!!: x=95850.0, xmax=3840
# Y wrong!!!: y=32324.0, ymax=2748
# X wrong!!!: x=95823.0, xmax=3840
# Y wrong!!!: y=31953.0, ymax=2748
# X wrong!!!: x=95850.0, xmax=3840
# Y wrong!!!: y=31582.0, ymax=2748
# X wrong!!!: x=95931.0, xmax=3840
# Y wrong!!!: y=31213.0, ymax=2748
# X wrong!!!: x=96065.0, xmax=3840
# Y wrong!!!: y=30850.0, ymax=2748
# X wrong!!!: x=96251.0, xmax=3840
# Y wrong!!!: y=30496.0, ymax=2748
# X wrong!!!: x=96488.0, xmax=3840
# Y wrong!!!: y=30153.0, ymax=2748
# X wrong!!!: x=96774.0, xmax=3840
# Y wrong!!!: y=29823.0, ymax=2748
# X wrong!!!: x=97106.0, xmax=3840
# Y wrong!!!: y=29510.0, ymax=2748
# X wrong!!!: x=97483.0, xmax=3840
# Y wrong!!!: y=29215.0, ymax=2748
# X wrong!!!: x=97902.0, xmax=3840
# Y wrong!!!: y=28941.0, ymax=2748
# X wrong!!!: x=98358.0, xmax=3840
# Y wrong!!!: y=28690.0, ymax=2748
# X wrong!!!: x=98849.0, xmax=3840
# Y wrong!!!: y=28463.0, ymax=2748
# X wrong!!!: x=99372.0, xmax=3840
# Y wrong!!!: y=28264.0, ymax=2748
# X wrong!!!: x=99921.0, xmax=3840
# Y wrong!!!: y=28092.0, ymax=2748
# X wrong!!!: x=100493.0, xmax=3840
# Y wrong!!!: y=27950.0, ymax=2748
# X wrong!!!: x=101083.0, xmax=3840
# Y wrong!!!: y=27838.0, ymax=2748
# X wrong!!!: x=101688.0, xmax=3840
# Y wrong!!!: y=27758.0, ymax=2748
# X wrong!!!: x=102301.0, xmax=3840
# Y wrong!!!: y=27709.0, ymax=2748
# X wrong!!!: x=102920.0, xmax=3840
# Y wrong!!!: y=27693.0, ymax=2748
# X wrong!!!: x=103539.0, xmax=3840
# Y wrong!!!: y=27709.0, ymax=2748
# X wrong!!!: x=104152.0, xmax=3840
# Y wrong!!!: y=27758.0, ymax=2748
# X wrong!!!: x=104757.0, xmax=3840
# Y wrong!!!: y=27838.0, ymax=2748
# X wrong!!!: x=105347.0, xmax=3840
# Y wrong!!!: y=27950.0, ymax=2748
# X wrong!!!: x=105919.0, xmax=3840
# Y wrong!!!: y=28092.0, ymax=2748
# X wrong!!!: x=106468.0, xmax=3840
# Y wrong!!!: y=28264.0, ymax=2748
# X wrong!!!: x=106991.0, xmax=3840
# Y wrong!!!: y=28463.0, ymax=2748
# X wrong!!!: x=107482.0, xmax=3840
# Y wrong!!!: y=28690.0, ymax=2748
# X wrong!!!: x=107938.0, xmax=3840
# Y wrong!!!: y=28941.0, ymax=2748
# X wrong!!!: x=108357.0, xmax=3840
# Y wrong!!!: y=29215.0, ymax=2748
# X wrong!!!: x=108734.0, xmax=3840
# Y wrong!!!: y=29510.0, ymax=2748
# X wrong!!!: x=109066.0, xmax=3840
# Y wrong!!!: y=29823.0, ymax=2748
# X wrong!!!: x=109352.0, xmax=3840
# Y wrong!!!: y=30153.0, ymax=2748
# X wrong!!!: x=109589.0, xmax=3840
# Y wrong!!!: y=30496.0, ymax=2748
# X wrong!!!: x=109775.0, xmax=3840
# Y wrong!!!: y=30850.0, ymax=2748
# X wrong!!!: x=109909.0, xmax=3840
# Y wrong!!!: y=31213.0, ymax=2748
# X wrong!!!: x=109990.0, xmax=3840
# Y wrong!!!: y=31582.0, ymax=2748
# X wrong!!!: x=110017.0, xmax=3840
# Y wrong!!!: y=31953.0, ymax=2748
# X wrong!!!: x=134860.0, xmax=3840
# Y wrong!!!: y=34793.0, ymax=2748
# X wrong!!!: x=134830.0, xmax=3840
# Y wrong!!!: y=35288.0, ymax=2748
# X wrong!!!: x=134741.0, xmax=3840
# Y wrong!!!: y=35779.0, ymax=2748
# X wrong!!!: x=134594.0, xmax=3840
# Y wrong!!!: y=36263.0, ymax=2748
# X wrong!!!: x=134389.0, xmax=3840
# Y wrong!!!: y=36736.0, ymax=2748
# X wrong!!!: x=134129.0, xmax=3840
# Y wrong!!!: y=37193.0, ymax=2748
# X wrong!!!: x=133814.0, xmax=3840
# Y wrong!!!: y=37633.0, ymax=2748
# X wrong!!!: x=133448.0, xmax=3840
# Y wrong!!!: y=38051.0, ymax=2748
# X wrong!!!: x=133034.0, xmax=3840
# Y wrong!!!: y=38444.0, ymax=2748
# X wrong!!!: x=132573.0, xmax=3840
# Y wrong!!!: y=38809.0, ymax=2748
# X wrong!!!: x=132071.0, xmax=3840
# Y wrong!!!: y=39144.0, ymax=2748
# X wrong!!!: x=131531.0, xmax=3840
# Y wrong!!!: y=39446.0, ymax=2748
# X wrong!!!: x=130956.0, xmax=3840
# Y wrong!!!: y=39712.0, ymax=2748
# X wrong!!!: x=130352.0, xmax=3840
# Y wrong!!!: y=39941.0, ymax=2748
# X wrong!!!: x=129723.0, xmax=3840
# Y wrong!!!: y=40130.0, ymax=2748
# X wrong!!!: x=129074.0, xmax=3840
# Y wrong!!!: y=40279.0, ymax=2748
# X wrong!!!: x=128409.0, xmax=3840
# Y wrong!!!: y=40387.0, ymax=2748
# X wrong!!!: x=127733.0, xmax=3840
# Y wrong!!!: y=40451.0, ymax=2748
# X wrong!!!: x=127053.0, xmax=3840
# Y wrong!!!: y=40473.0, ymax=2748
# X wrong!!!: x=126373.0, xmax=3840
# Y wrong!!!: y=40451.0, ymax=2748
# X wrong!!!: x=125697.0, xmax=3840
# Y wrong!!!: y=40387.0, ymax=2748
# X wrong!!!: x=125032.0, xmax=3840
# Y wrong!!!: y=40279.0, ymax=2748
# X wrong!!!: x=124383.0, xmax=3840
# Y wrong!!!: y=40130.0, ymax=2748
# X wrong!!!: x=123754.0, xmax=3840
# Y wrong!!!: y=39941.0, ymax=2748
# X wrong!!!: x=123150.0, xmax=3840
# Y wrong!!!: y=39712.0, ymax=2748
# X wrong!!!: x=122575.0, xmax=3840
# Y wrong!!!: y=39446.0, ymax=2748
# X wrong!!!: x=122035.0, xmax=3840
# Y wrong!!!: y=39144.0, ymax=2748
# X wrong!!!: x=121533.0, xmax=3840
# Y wrong!!!: y=38809.0, ymax=2748
# X wrong!!!: x=121072.0, xmax=3840
# Y wrong!!!: y=38444.0, ymax=2748
# X wrong!!!: x=120658.0, xmax=3840
# Y wrong!!!: y=38051.0, ymax=2748
# X wrong!!!: x=120292.0, xmax=3840
# Y wrong!!!: y=37633.0, ymax=2748
# X wrong!!!: x=119977.0, xmax=3840
# Y wrong!!!: y=37193.0, ymax=2748
# X wrong!!!: x=119717.0, xmax=3840
# Y wrong!!!: y=36736.0, ymax=2748
# X wrong!!!: x=119512.0, xmax=3840
# Y wrong!!!: y=36263.0, ymax=2748
# X wrong!!!: x=119365.0, xmax=3840
# Y wrong!!!: y=35779.0, ymax=2748
# X wrong!!!: x=119276.0, xmax=3840
# Y wrong!!!: y=35288.0, ymax=2748
# X wrong!!!: x=119246.0, xmax=3840
# Y wrong!!!: y=34793.0, ymax=2748
# X wrong!!!: x=119276.0, xmax=3840
# Y wrong!!!: y=34298.0, ymax=2748
# X wrong!!!: x=119365.0, xmax=3840
# Y wrong!!!: y=33807.0, ymax=2748
# X wrong!!!: x=119512.0, xmax=3840
# Y wrong!!!: y=33323.0, ymax=2748
# X wrong!!!: x=119717.0, xmax=3840
# Y wrong!!!: y=32850.0, ymax=2748
# X wrong!!!: x=119977.0, xmax=3840
# Y wrong!!!: y=32393.0, ymax=2748
# X wrong!!!: x=120292.0, xmax=3840
# Y wrong!!!: y=31953.0, ymax=2748
# X wrong!!!: x=120658.0, xmax=3840
# Y wrong!!!: y=31535.0, ymax=2748
# X wrong!!!: x=121072.0, xmax=3840
# Y wrong!!!: y=31142.0, ymax=2748
# X wrong!!!: x=121533.0, xmax=3840
# Y wrong!!!: y=30777.0, ymax=2748
# X wrong!!!: x=122035.0, xmax=3840
# Y wrong!!!: y=30442.0, ymax=2748
# X wrong!!!: x=122575.0, xmax=3840
# Y wrong!!!: y=30140.0, ymax=2748
# X wrong!!!: x=123150.0, xmax=3840
# Y wrong!!!: y=29874.0, ymax=2748
# X wrong!!!: x=123754.0, xmax=3840
# Y wrong!!!: y=29645.0, ymax=2748
# X wrong!!!: x=124383.0, xmax=3840
# Y wrong!!!: y=29456.0, ymax=2748
# X wrong!!!: x=125032.0, xmax=3840
# Y wrong!!!: y=29307.0, ymax=2748
# X wrong!!!: x=125697.0, xmax=3840
# Y wrong!!!: y=29199.0, ymax=2748
# X wrong!!!: x=126373.0, xmax=3840
# Y wrong!!!: y=29135.0, ymax=2748
# X wrong!!!: x=127053.0, xmax=3840
# Y wrong!!!: y=29113.0, ymax=2748
# X wrong!!!: x=127733.0, xmax=3840
# Y wrong!!!: y=29135.0, ymax=2748
# X wrong!!!: x=128409.0, xmax=3840
# Y wrong!!!: y=29199.0, ymax=2748
# X wrong!!!: x=129074.0, xmax=3840
# Y wrong!!!: y=29307.0, ymax=2748
# X wrong!!!: x=129723.0, xmax=3840
# Y wrong!!!: y=29456.0, ymax=2748
# X wrong!!!: x=130352.0, xmax=3840
# Y wrong!!!: y=29645.0, ymax=2748
# X wrong!!!: x=130956.0, xmax=3840
# Y wrong!!!: y=29874.0, ymax=2748
# X wrong!!!: x=131531.0, xmax=3840
# Y wrong!!!: y=30140.0, ymax=2748
# X wrong!!!: x=132071.0, xmax=3840
# Y wrong!!!: y=30442.0, ymax=2748
# X wrong!!!: x=132573.0, xmax=3840
# Y wrong!!!: y=30777.0, ymax=2748
# X wrong!!!: x=133034.0, xmax=3840
# Y wrong!!!: y=31142.0, ymax=2748
# X wrong!!!: x=133448.0, xmax=3840
# Y wrong!!!: y=31535.0, ymax=2748
# X wrong!!!: x=133814.0, xmax=3840
# Y wrong!!!: y=31953.0, ymax=2748
# X wrong!!!: x=134129.0, xmax=3840
# Y wrong!!!: y=32393.0, ymax=2748
# X wrong!!!: x=134389.0, xmax=3840
# Y wrong!!!: y=32850.0, ymax=2748
# X wrong!!!: x=134594.0, xmax=3840
# Y wrong!!!: y=33323.0, ymax=2748
# X wrong!!!: x=134741.0, xmax=3840
# Y wrong!!!: y=33807.0, ymax=2748
# X wrong!!!: x=134830.0, xmax=3840
# Y wrong!!!: y=34298.0, ymax=2748
# X wrong!!!: x=134860.0, xmax=3840
# Y wrong!!!: y=34793.0, ymax=2748
# X wrong!!!: x=161833.0, xmax=3840
# Y wrong!!!: y=40474.0, ymax=2748
# X wrong!!!: x=161795.0, xmax=3840
# Y wrong!!!: y=40969.0, ymax=2748
# X wrong!!!: x=161682.0, xmax=3840
# Y wrong!!!: y=41460.0, ymax=2748
# X wrong!!!: x=161494.0, xmax=3840
# Y wrong!!!: y=41944.0, ymax=2748
# X wrong!!!: x=161234.0, xmax=3840
# Y wrong!!!: y=42417.0, ymax=2748
# X wrong!!!: x=160902.0, xmax=3840
# Y wrong!!!: y=42874.0, ymax=2748
# X wrong!!!: x=160502.0, xmax=3840
# Y wrong!!!: y=43314.0, ymax=2748
# X wrong!!!: x=160036.0, xmax=3840
# Y wrong!!!: y=43732.0, ymax=2748
# X wrong!!!: x=159508.0, xmax=3840
# Y wrong!!!: y=44125.0, ymax=2748
# X wrong!!!: x=158923.0, xmax=3840
# Y wrong!!!: y=44490.0, ymax=2748
# X wrong!!!: x=158283.0, xmax=3840
# Y wrong!!!: y=44825.0, ymax=2748
# X wrong!!!: x=157596.0, xmax=3840
# Y wrong!!!: y=45127.0, ymax=2748
# X wrong!!!: x=156864.0, xmax=3840
# Y wrong!!!: y=45393.0, ymax=2748
# X wrong!!!: x=156096.0, xmax=3840
# Y wrong!!!: y=45622.0, ymax=2748
# X wrong!!!: x=155295.0, xmax=3840
# Y wrong!!!: y=45811.0, ymax=2748
# X wrong!!!: x=154468.0, xmax=3840
# Y wrong!!!: y=45960.0, ymax=2748
# X wrong!!!: x=153622.0, xmax=3840
# Y wrong!!!: y=46068.0, ymax=2748
# X wrong!!!: x=152762.0, xmax=3840
# Y wrong!!!: y=46132.0, ymax=2748
# X wrong!!!: x=151896.0, xmax=3840
# Y wrong!!!: y=46154.0, ymax=2748
# X wrong!!!: x=151030.0, xmax=3840
# Y wrong!!!: y=46132.0, ymax=2748
# X wrong!!!: x=150170.0, xmax=3840
# Y wrong!!!: y=46068.0, ymax=2748
# X wrong!!!: x=149324.0, xmax=3840
# ...
# [177/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/10393.txt
# [178/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/C1L003.txt
# [178/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/C1L003.txt
# [179/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/21.txt
# [179/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/21.txt
# [180/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/p_tr_106.txt
# [180/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/p_tr_106.txt
# [181/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/36.txt
# [181/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/36.txt
# [182/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/u_tr_95.txt
# [182/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/u_tr_95.txt
# [183/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/BE_20X001.txt
# [183/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/BE_20X001.txt
# [184/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_35_cut_want.txt
# [184/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_35_cut_want.txt
# [185/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/p_tr_52.txt
# [185/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/p_tr_52.txt
# [186/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_24_cut_want.txt
# [186/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_24_cut_want.txt
# [187/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/C1L009.txt
# [187/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/C1L009.txt
# [188/188] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/c_tr_31_cut_want.txt
# [188/188] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/train/det/c_tr_31_cut_want.txt
# Start extracting data in val........
# created folder :  /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val
# [1/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_68_cut_want.txt
# [1/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_68_cut_want.txt
# [2/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_35.txt
# [2/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_35.txt
# [3/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X005.txt
# [3/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X005.txt
# [4/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/CK006.txt
# [4/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/CK006.txt
# [5/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/96.txt
# [5/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/96.txt
# [6/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_79.txt
# [6/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_79.txt
# [7/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X010.txt
# [7/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X010.txt
# [8/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_121_cut_want.txt
# [8/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_121_cut_want.txt
# [9/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_210.txt
# [9/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_210.txt
# [10/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X015.txt
# [10/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X015.txt
# [11/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/C1L006.txt
# [11/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/C1L006.txt
# [12/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_277.txt
# [12/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_277.txt
# [13/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_160.txt
# [13/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_160.txt
# [14/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X007.txt
# [14/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X007.txt
# [15/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/39.txt
# [15/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/39.txt
# [16/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_131_cut_want.txt
# [16/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_131_cut_want.txt
# [17/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/177.txt
# [17/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/177.txt
# [18/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_51_cut_want.txt
# [18/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_51_cut_want.txt
# [19/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_115.txt
# [19/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_115.txt
# [20/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/CK004.txt
# [20/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/CK004.txt
# [21/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/10394.txt
# [21/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/10394.txt
# [22/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/27.txt
# [22/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/27.txt
# [23/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X002.txt
# [23/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X002.txt
# [24/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_10.txt
# [24/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_10.txt
# [25/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X003.txt
# [25/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X003.txt
# [26/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/42.txt
# [26/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/42.txt
# [27/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_61.txt
# [27/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_61.txt
# [28/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_158_cut_want.txt
# [28/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_158_cut_want.txt
# [29/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_102.txt
# [29/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_102.txt
# [30/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_91_cut_want.txt
# [30/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_91_cut_want.txt
# [31/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_80.txt
# [31/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_80.txt
# [32/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/59.txt
# [32/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/59.txt
# [33/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/C1L010.txt
# [33/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/C1L010.txt
# [34/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/10106.txt
# [34/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/10106.txt
# [35/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_149.txt
# [35/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_149.txt
# [36/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/197.txt
# [36/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/197.txt
# [37/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_103.txt
# [37/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_103.txt
# [38/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/182.txt
# [38/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/182.txt
# [39/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_44.txt
# [39/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_44.txt
# [40/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/BE_20X004.txt
# [40/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/BE_20X004.txt
# [41/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/p_tr_36.txt
# [41/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/p_tr_36.txt
# [42/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/c_tr_117_cut_want.txt
# [42/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/c_tr_117_cut_want.txt
# [43/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/C1L002.txt
# [43/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/C1L002.txt
# [44/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/50.txt
# [44/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/50.txt
# [45/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_64.txt
# [45/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_64.txt
# [46/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/CK003.txt
# [46/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/CK003.txt
# [47/47] extract and load seg annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/u_tr_215.txt
# [47/47] extract and load det annotations to: /mnt/linux/abrc/abrc/dataset/stomaVDP/label-Leafnet-and-others/labels/val/det/u_tr_215.txt
