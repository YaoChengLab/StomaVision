# %% [markdown]
# ### Extract file names from dataset

# %%
import os

dataset_dir = "/mnt/local/abrc/parsed_dataset"
dataset_name = "StomaVision-multilabel"

img_extention = ["jpg", "png", "tif"]
parse_dirs = ["train", "val", "test"]

for d in parse_dirs:
    img_list = os.listdir(os.path.join(dataset_dir, dataset_name, "images", d))
    output_filename = os.path.join(dataset_dir, dataset_name, d + ".txt")

    # clear data in the output_file
    with open(output_filename, "w") as f:
        pass

    for idx, img in enumerate(img_list):
        if img.split(".")[-1] in img_extention:
            print(img)
            with open(output_filename, "a") as f:
                f.write(os.path.join("./images", d, img))
                if idx < len(img_list) - 1:
                    f.write("\n")

print("file name extraction complete......")
# Out:
# u_tr_95.png
# e3a25163-row-2-column-1.jpg
# b648ebd0-row-2-column-2.jpg
# p_tr_83.png
# p_tr_16.png
# c_tr_154_cut_want.jpg
# u_tr_236.png
# 20200615_07-12.3.3.jpg
# 0615_03-11.4.2.jpg
# 1bde0564-row-1-column-2_18.jpg
# 46cf211a-row-1-column-2.jpg
# dc8cb162-row-2-column-2_3.jpg
# p_tr_103.png
# p_tr_113.png
# 0615_08-13.1.5.jpg
# cff05454-row-2-column-1_11.jpg
# 0611_03-07.2.5.jpg
# d90a0b35-row-1-column-2_4.jpg
# c_tr_158_cut_want.jpg
# 5fa064a7-row-1-column-1_8.jpg
# 0611_04-08.3.5.jpg
# fb9d0dab-row-1-column-2_3.jpg
# C1L001.jpg
# u_tr_283.png
# 20200615_07-15.4.2.jpg
# u_tr_80.png
# c_tr_5_cut_want.jpg
# e6113b1d-row-2-column-1_7.jpg
# 10fbeab7-row-1-column-2_12.jpg
# 767b3f41-row-2-column-1_16.jpg
# 20200615_16-12.2.2.jpg
# 28a92e8a-row-2-column-2.png
# 190.jpg
# 1def49bd-row-3-column-2_5.jpg
# p_tr_30.png
# 05847007-row-1-column-1_18.jpg
# CK001.jpg
# f3f72e9e-row-2-column-2_1.jpg
# b6158026-row-1-column-1_7.jpg
# 4fbac8d3-row-1-column-1.png
# ada404a7-row-2-column-1_5.jpg
# u_tr_149.png
# ed81f1c2-row-2-column-2_8.jpg
# c_tr_70_cut_want.jpg
# 20200615_07-8.1.4.jpg
# 4856c818-row-2-column-2_2.jpg
# CK003.jpg
# 49961964-RU.jpg
# 935fe264-row-1-column-2_11.jpg
# 18240073-row-2-column-1.png
# 13.jpg
# 10052.jpg
# d4f0063d-row-2-column-1_14.jpg
# 7fcb6ff8-row-2-column-2_11.jpg
# ef6ca65e-row-2-column-1_18.jpg
# 70e44e9c-row-1-column-1_1.jpg
# 18993462-row-2-column-1_13.jpg
# p_tr_7.png
# f0ad5ea2-row-2-column-2_1.jpg
# u_tr_245.png
# 20200611_12-02.3.3.jpg
# 0611_13-03.1.1.jpg
# u_tr_210.png
# 9b4fe6c4-row-1-column-1_3.jpg
# f7a4659c-row-2-column-1_2.jpg
# C1L003.jpg
# 50767991-row-2-column-1_21.jpg
# 27829c91-row-1-column-2_18.jpg
# c_tr_24_cut_want.jpg
# de5ca518-row-2-column-2_6.jpg
# bb15e19d-row-2-column-2_7.jpg
# p_tr_68.png
# u_tr_242.png
# u_tr_42.png
# c_tr_56_cut_want.jpg
# C1L005.jpg
# u_tr_222.png
# C1L010.jpg
# 150.jpg
# d24f123c-row-2-column-2.jpg
# c_tr_117_cut_want.jpg
# 4719a9b1-row-1-column-1_12.jpg
# bc585c60-20240501134622_merger.jpg
# 20200611_01-01.3.4.jpg
# 0deb6fff-row-1-column-1_4.jpg
# c6dc08b5-row-1-column-2_10.jpg
# 72de742b-row-1-column-2_1.jpg
# c_tr_36_cut_want.jpg
# 61d7239c-row-2-column-1_5.jpg
# u_tr_72.png
# u_tr_212.png
# fb89fb4a-row-3-column-2_2.jpg
# 107.jpg
# 10203.jpg
# c_tr_131_cut_want.jpg
# 11c90367-row-1-column-2_16.jpg
# 1dfbf3fb-row-2-column-1_6.jpg
# p_tr_52.png
# dd00d6d5-row-1-column-2.jpg
# c560d333-row-1-column-1_13.jpg
# 832a5efd-row-1-column-2_8.jpg
# u_tr_54.png
# fbc18b75-row-2-column-1_4.jpg
# 10356.jpg
# eed28987-row-1-column-2_13.jpg
# f8a60ede-row-1-column-2_15.jpg
# p_tr_38.png
# p_tr_34.png
# 76b855e1-row-1-column-1_13.jpg
# u_tr_281.png
# u_tr_294.png
# p_tr_70.png
# 10060.jpg
# 0611_03-03.3.5.jpg
# f3ec59fc-row-2-column-1_12.jpg
# 10142.jpg
# CK002.jpg
# file name extraction complete......

# %% [markdown]
# ### Convert Labels from COCO JSON instance to Yolov7 compatible polygon label format

# %%
import os, json, shutil

dataset_dir = "/mnt/local/abrc/parsed_dataset"
dataset_name = "StomaVision-multilabel"

img_extention = ["jpg", "png", "tif"]
parse_dirs = ["train", "val", "test"]

for d in parse_dirs:
    print(f"Start extracting data in {d}........")
    # Load label JSON file
    orig_annotations = None
    with open(
        os.path.join(dataset_dir, dataset_name, "labels", f"labels_{d}.json"), "r"
    ) as f_input:
        orig_annotations = json.load(f_input)

    dir = os.path.join(dataset_dir, dataset_name, "labels", d)
    CHECK_FOLDER = os.path.isdir(dir)

    if not CHECK_FOLDER:  # If folder doesn't exist, then create it.
        os.makedirs(os.path.join(dir, "seg"))
        os.makedirs(os.path.join(dir, "det"))
        print("created folder : ", dir)
    else:  # Reset folder if it exists.
        print(dir, "folder already exists.")
        shutil.rmtree(dir, ignore_errors=True)
        print("delete folder : ", dir)
        os.makedirs(os.path.join(dir, "seg"))
        os.makedirs(os.path.join(dir, "det"))
        print("created folder : ", dir)

    # Iterate through images in the JSON file
    for i, img in enumerate(orig_annotations):
        # Save Yolov7 annotation for instance segmentation
        output_filename = img["file_name"].split("/")[-1]  # get image name
        output_filename = os.path.splitext(output_filename)[0]  # remove extension
        output_filename = os.path.join(
            dataset_dir, dataset_name, "labels", d, f"{output_filename}.txt"
        )  # get full file name

        print(
            f"[{i+1}/{len(orig_annotations)}] extract and load seg annotations to: {output_filename}"
        )

        x_max = img["width"]
        y_max = img["height"]

        # Prepare and save segmentation annotations
        with open(output_filename, "w") as f_output:
            # iterate through annotations in each image.
            for idx, anno in enumerate(img["annotations"]):
                output = ""  # reset output
                output = output + str(anno["category_id"]) + " "  # add category id
                # save segmentation
                for idy, num in enumerate(anno["segmentation"][0]):
                    # normalise annotation
                    if idy % 2 == 0:  # odd number
                        output = output + str(round(num / x_max, 6))
                        if num / x_max > 1:
                            print(f"X wrong!!!: x={num}, xmax={x_max}")
                    else:  # even number
                        output = output + str(round(num / y_max, 6))
                        if num / y_max > 1:
                            print(f"Y wrong!!!: y={num}, ymax={y_max}")
                    if idy < len(anno["segmentation"][0]) - 1:
                        output = output + " "
                if idx < len(img["annotations"]) - 1:
                    output = output + "\n"
                f_output.write(output)

        # Save Yolov7 annotation for object detection
        output_filename = img["file_name"].split("/")[-1]  # get image name
        output_filename = os.path.splitext(output_filename)[0]  # remove extension
        output_filename = os.path.join(
            dataset_dir, dataset_name, "labels", d, "det", f"{output_filename}.txt"
        )  # get full file name

        print(
            f"[{i+1}/{len(orig_annotations)}] extract and load det annotations to: {output_filename}"
        )

        x_max = img["width"]
        y_max = img["height"]

        # Prepare and save detection annotations
        with open(output_filename, "w") as f_output:
            # iterate through annotations in each image.
            for idx, anno in enumerate(img["annotations"]):
                # reset output
                output = ""

                """
                Bbox annotation in Detectron2 is:
                anno['bbox'][0]: left top x
                anno['bbox'][1]: left top y
                anno['bbox'][1]: right bottom x
                anno['bbox'][1]: right bottom y
                """
                x_0 = anno["bbox"][0]
                y_0 = anno["bbox"][1]
                x_1 = anno["bbox"][2]
                y_1 = anno["bbox"][3]

                # add category id
                output = output + str(anno["category_id"]) + " "

                # add centre x axis
                x_centre = round((x_0 + x_1) / (2 * x_max), 6)
                if x_centre > 1:
                    print(f"X centre is wrong!!! centre_x={x_centre}, xmax={x_max}")
                output = output + str(x_centre) + " "

                # add centre y axis
                y_centre = round((y_0 + y_1) / (2 * y_max), 6)
                if y_centre > 1:
                    print(f"Y centre is wrong!!!: centre_x={y_centre}, ymax={y_max}")
                output = output + str(y_centre) + " "

                # add width
                width = round((x_1 - x_0) / (x_max), 6)
                if (width / 2) + x_centre > x_max:
                    print(f"width is wrong: width={width}, xmax={x_max}")
                if width < 0:
                    print(f"width is minus: width={width}, xmax={x_max}")
                output = output + str(width) + " "

                # add height
                height = round((y_1 - y_0) / (y_max), 6)
                if (height / 2) + y_centre > y_max:
                    print(f"width is wrong: height={height}, xmax={y_max}")
                if height < 0:
                    print(f"height is minus: width={height}, xmax={y_max}")
                output = output + str(height)

                if idx < len(img["annotations"]) - 1:
                    output = output + "\n"
                f_output.write(output)
# Out:
# Start extracting data in train........
# created folder :  /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train
# [1/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/1f7d62b1-row-1-column-1.txt
# [1/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/1f7d62b1-row-1-column-1.txt
# [2/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/5fa064a7-row-1-column-1_8.txt
# [2/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/5fa064a7-row-1-column-1_8.txt
# [3/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/p_tr_113.txt
# [3/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/p_tr_113.txt
# [4/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/20200615_10-15.4.1.txt
# [4/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train
extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/21.txt
# [38/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/C1L002.txt
# [38/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/C1L002.txt
# [39/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/106bf26f-row-2-column-2_2.txt
# [39/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/106bf26f-row-2-column-2_2.txt
# [40/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/u_tr_210.txt
# [40/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/u_tr_210.txt
# [41/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/5e10c924-row-2-column-2_13.txt
# [41/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/5e10c924-row-2-column-2_13.txt
# [42/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/20200615_09-8.3.4.txt
# [42/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/20200615_09-8.3.4.txt
# [43/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/p_tr_102.txt
# [43/399] extract and load det annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/det/p_tr_102.txt
# [44/399] extract and load seg annotations to: /mnt/local/abrc/parsed_dataset/StomaVision-multilabel/labels/train/10333.txt
# X wrong!!!: x=3230.0, xmax=1360
# Y wrong!!!: y=4167.0, ymax=1024
# X wrong!!!: x=3224.0, xmax=1360
# Y wrong!!!: y=4185.0, ymax=1024
# X wrong!!!: x=3205.0, xmax=1360
# Y wrong!!!: y=4204.0, ymax=1024
# X wrong!!!: x=3175.0, xmax=1360
# Y wrong!!!: y=4222.0, ymax=1024
# X wrong!!!: x=3133.0, xmax=1360
# Y wrong!!!: y=4239.0, ymax=1024
# X wrong!!!: x=3079.0, xmax=1360
# Y wrong!!!: y=4256.0, ymax=1024
# X wrong!!!: x=3014.0, xmax=1360
# Y wrong!!!: y=4272.0, ymax=1024
# X wrong!!!: x=2938.0, xmax=1360
# Y wrong!!!: y=4288.0, ymax=1024
# X wrong!!!: x=2852.0, xmax=1360
# Y wrong!!!: y=4303.0, ymax=1024
# X wrong!!!: x=2757.0, xmax=1360
# Y wrong!!!: y=4316.0, ymax=1024
# X wrong!!!: x=2653.0, xmax=1360
# Y wrong!!!: y=4329.0, ymax=1024
# X wrong!!!: x=2541.0, xmax=1360
# Y wrong!!!: y=4340.0, ymax=1024
# X wrong!!!: x=2422.0, xmax=1360
# Y wrong!!!: y=4350.0, ymax=1024
# X wrong!!!: x=2298.0, xmax=1360
# Y wrong!!!: y=4358.0, ymax=1024
# X wrong!!!: x=2167.0, xmax=1360
# Y wrong!!!: y=4365.0, ymax=1024
# X wrong!!!: x=2033.0, xmax=1360
# Y wrong!!!: y=4371.0, ymax=1024
# X wrong!!!: x=1895.0, xmax=1360
# Y wrong!!!: y=4375.0, ymax=1024
# X wrong!!!: x=1756.0, xmax=1360
# Y wrong!!!: y=4377.0, ymax=1024
# X wrong!!!: x=1615.0, xmax=1360
# Y wrong!!!: y=4378.0, ymax=1024
# X wrong!!!: x=1474.0, xmax=1360
# Y wrong!!!: y=4377.0, ymax=1024
# Y wrong!!!: y=4375.0, ymax=1024
# Y wrong!!!: y=4371.0, ymax=1024
# Y wrong!!!: y=4365.0, ymax=1024
# Y wrong!!!: y=4358.0, ymax=1024
# Y wrong!!!: y=4350.0, ymax=1024
# Y wrong!!!: y=4340.0, ymax=1024
# Y wrong!!!: y=4329.0, ymax=1024
# Y wrong!!!: y=4316.0, ymax=1024
# Y wrong!!!: y=4303.0, ymax=1024
# Y wrong!!!: y=4288.0, ymax=1024
# Y wrong!!!: y=4272.0, ymax=1024
# Y wrong!!!: y=4256.0, ymax=1024
# Y wrong!!!: y=4239.0, ymax=1024
# Y wrong!!!: y=4222.0, ymax=1024
# Y wrong!!!: y=4204.0, ymax=1024
# Y wrong!!!: y=4185.0, ymax=1024
# Y wrong!!!: y=4167.0, ymax=1024
# Y wrong!!!: y=4149.0, ymax=1024
# Y wrong!!!: y=4130.0, ymax=1024
# Y wrong!!!: y=4112.0, ymax=1024
# Y wrong!!!: y=4095.0, ymax=1024
# Y wrong!!!: y=4078.0, ymax=1024
# Y wrong!!!: y=4062.0, ymax=1024
# Y wrong!!!: y=4046.0, ymax=1024
# Y wrong!!!: y=4031.0, ymax=1024
# Y wrong!!!: y=4018.0, ymax=1024
# Y wrong!!!: y=4005.0, ymax=1024
# Y wrong!!!: y=3994.0, ymax=1024
# Y wrong!!!: y=3984.0, ymax=1024
# Y wrong!!!: y=3976.0, ymax=1024
# Y wrong!!!: y=3969.0, ymax=1024
# Y wrong!!!: y=3963.0, ymax=1024
# Y wrong!!!: y=3959.0, ymax=1024
# X wrong!!!: x=1474.0, xmax=1360
# Y wrong!!!: y=3957.0, ymax=1024
# X wrong!!!: x=1615.0, xmax=1360
# Y wrong!!!: y=3956.0, ymax=1024
# X wrong!!!: x=1756.0, xmax=1360
# Y wrong!!!: y=3957.0, ymax=1024
# X wrong!!!: x=1895.0, xmax=1360
# Y wrong!!!: y=3959.0, ymax=1024
# X wrong!!!: x=2033.0, xmax=1360
# Y wrong!!!: y=3963.0, ymax=1024
# X wrong!!!: x=2167.0, xmax=1360
# Y wrong!!!: y=3969.0, ymax=1024
# X wrong!!!: x=2298.0, xmax=1360
# Y wrong!!!: y=3976.0, ymax=1024
# X wrong!!!: x=2422.0, xmax=1360
# Y wrong!!!: y=3984.0, ymax=1024
# X wrong!!!: x=2541.0, xmax=1360
# Y wrong!!!: y=3994.0, ymax=1024
# X wrong!!!: x=2653.0, xmax=1360
# Y wrong!!!: y=4005.0, ymax=1024
# X wrong!!!: x=2757.0, xmax=1360
# Y wrong!!!: y=4018.0, ymax=1024
# X wrong!!!: x=2852.0, xmax=1360
# Y wrong!!!: y=4031.0, ymax=1024
# X wrong!!!: x=2938.0, xmax=1360
# Y wrong!!!: y=4046.0, ymax=1024
# X wrong!!!: x=3014.0, xmax=1360
# Y wrong!!!: y=4062.0, ymax=1024
# X wrong!!!: x=3079.0, xmax=1360
# Y wrong!!!: y=4078.0, ymax=1024
# X wrong!!!: x=3133.0, xmax=1360
# Y wrong!!!: y=4095.0, ymax=1024
# X wrong!!!: x=3175.0, xmax=1360
# Y wrong!!!: y=4112.0, ymax=1024
# X wrong!!!: x=3205.0, xmax=1360
# Y wrong!!!: y=4130.0, ymax=1024
# X wrong!!!: x=3224.0, xmax=1360
# Y wrong!!!: y=4149.0, ymax=1024
# X wrong!!!: x=3230.0, xmax=1360
# Y wrong!!!: y=4167.0, ymax=1024
# X wrong!!!: x=26668.0, xmax=1360
# Y wrong!!!: y=3103.0, ymax=1024
# X wrong!!!: x=26662.0, xmax=1360
# Y wrong!!!: y=3128.0, ymax=1024
# X wrong!!!: x=26644.0, xmax=1360
# Y wrong!!!: y=3154.0, ymax=1024
# X wrong!!!: x=26615.0, xmax=1360
# Y wrong!!!: y=3179.0, ymax=1024
# X wrong!!!: x=26573.0, xmax=1360
# Y wrong!!!: y=3203.0, ymax=1024
# X wrong!!!: x=26521.0, xmax=1360
# Y wrong!!!: y=3226.0, ymax=1024
# X wrong!!!: x=26458.0, xmax=1360
# Y wrong!!!: y=3249.0, ymax=1024
# X wrong!!!: x=26384.0, xmax=1360
# Y wrong!!!: y=3270.0, ymax=1024
# X wrong!!!: x=26301.0, xmax=1360
# Y wrong!!!: y=3291.0, ymax=1024
# X wrong!!!: x=26208.0, xmax=1360
# Y wrong!!!: y=3309.0, ymax=1024
# X wrong!!!: x=26107.0, xmax=1360
# Y wrong!!!: y=3327.0, ymax=1024
# X wrong!!!: x=25999.0, xmax=1360
# Y wrong!!!: y=3342.0, ymax=1024
# X wrong!!!: x=25883.0, xmax=1360
# Y wrong!!!: y=3356.0, ymax=1024
# X wrong!!!: x=25762.0, xmax=1360
# Y wrong!!!: y=3368.0, ymax=1024
# X wrong!!!: x=25635.0, xmax=1360
# Y wrong!!!: y=3377.0, ymax=1024
# X wrong!!!: x=25504.0, xmax=1360
# Y wrong!!!: y=3385.0, ymax=1024
# X wrong!!!: x=25371.0, xmax=1360
# Y wrong!!!: y=3391.0, ymax=1024
# X wrong!!!: x=25235.0, xmax=1360
# Y wrong!!!: y=3394.0, ymax=1024
# X wrong!!!: x=25098.0, xmax=1360
# Y wrong!!!: y=3395.0, ymax=1024
# X wrong!!!: x=24961.0, xmax=1360
# Y wrong!!!: y=3394.0, ymax=1024
# X wrong!!!: x=24825.0, xmax=1360
# Y wrong!!!: y=3391.0, ymax=1024
# X wrong!!!: x=24692.0, xmax=1360
# Y wrong!!!: y=3385.0, ymax=1024
# X wrong!!!: x=24561.0, xmax=1360
# Y wrong!!!: y=3377.0, ymax=1024
# X wrong!!!: x=24434.0, xmax=1360
# Y wrong!!!: y=3368.0, ymax=1024
# X wrong!!!: x=24313.0, xmax=1360
# Y wrong!!!: y=3356.0, ymax=1024
# X wrong!!!: x=24197.0, xmax=1360
# Y wrong!!!: y=3342.0, ymax=1024
# X wrong!!!: x=24089.0, xmax=1360
# Y wrong!!!: y=3327.0, ymax=1024
# X wrong!!!: x=23988.0, xmax=1360
# Y wrong!!!: y=3309.0, ymax=1024
# X wrong!!!: x=23895.0, xmax=1360
# Y wrong!!!: y=3291.0, ymax=1024
# X wrong!!!: x=23812.0, xmax=1360
# Y wrong!!!: y=3270.0, ymax=1024
# X wrong!!!: x=23738.0, xmax=1360
# Y wrong!!!: y=3249.0, ymax=1024
# X wrong!!!: x=23675.0, xmax=1360
# Y wrong!!!: y=3226.0, ymax=1024
# X wrong!!!: x=23623.0, xmax=1360
# Y wrong!!!: y=3203.0, ymax=1024
# X wrong!!!: x=23581.0, xmax=1360
# Y wrong!!!: y=3179.0, ymax=1024
# X wrong!!!: x=23552.0, xmax=1360
# Y wrong!!!: y=3154.0, ymax=1024
# X wrong!!!: x=23534.0, xmax=1360
# Y wrong!!!: y=3128.0, ymax=1024
# X wrong!!!: x=23528.0, xmax=1360
# Y wrong!!!: y=3103.0, ymax=1024
# X wrong!!!: x=23534.0, xmax=1360
# Y wrong!!!: y=3078.0, ymax=1024
# X wrong!!!: x=23552.0, xmax=1360
# Y wrong!!!: y=3052.0, ymax=1024
# X wrong!!!: x=23581.0, xmax=1360
# Y wrong!!!: y=3027.0, ymax=1024
# X wrong!!!: x=23623.0, xmax=1360
# Y wrong!!!: y=3003.0, ymax=1024
# X wrong!!!: x=23675.0, xmax=1360
# Y wrong!!!: y=2980.0, ymax=1024
# X wrong!!!: x=23738.0, xmax=1360
# Y wrong!!!: y=2957.0, ymax=1024
# X wrong!!!: x=23812.0, xmax=1360
# Y wrong!!!: y=2936.0, ymax=1024
# X wrong!!!: x=23895.0, xmax=1360
# Y wrong!!!: y=2915.0, ymax=1024
# X wrong!!!: x=23988.0, xmax=1360
# Y wrong!!!: y=2897.0, ymax=1024
# X wrong!!!: x=24089.0, xmax=1360
# Y wrong!!!: y=2879.0, ymax=1024
# X wrong!!!: x=24197.0, xmax=1360
# Y wrong!!!: y=2864.0, ymax=1024
# X wrong!!!: x=24313.0, xmax=1360
# Y wrong!!!: y=2850.0, ymax=1024
# X wrong!!!: x=24434.0, xmax=1360
# Y wrong!!!: y=2838.0, ymax=1024
# X wrong!!!: x=24561.0, xmax=1360
# Y wrong!!!: y=2829.0, ymax=1024
# X wrong!!!: x=24692.0, xmax=1360
# Y wrong!!!: y=2821.0, ymax=1024
# X wrong!!!: x=24825.0, xmax=1360
# Y wrong!!!: y=2815.0, ymax=1024
# X wrong!!!: x=24961.0, xmax=1360
# Y wrong!!!: y=2812.0, ymax=1024
# X wrong!!!: x=25098.0, xmax=1360
# Y wrong!!!: y=2811.0, ymax=1024
# X wrong!!!: x=25235.0, xmax=1360
# Y wrong!!!: y=2812.0, ymax=1024
# X wrong!!!: x=25371.0, xmax=1360
# Y wrong!!!: y=2815.0, ymax=1024
# X wrong!!!: x=25504.0, xmax=1360
# Y wrong!!!: y=2821.0, ymax=1024
# X wrong!!!: x=25635.0, xmax=1360
# Y wrong!!!: y=2829.0, ymax=1024
# X wrong!!!: x=25762.0, xmax=1360
# Y wrong!!!: y=2838.0, ymax=1024
# X wrong!!!: x=25883.0, xmax=1360
# Y wrong!!!: y=2850.0, ymax=1024
# X wrong!!!: x=25999.0, xmax=1360
# Y wrong!!!: y=2864.0, ymax=1024
# X wrong!!!: x=26107.0, xmax=1360
# Y wrong!!!: y=2879.0, ymax=1024
# X wrong!!!: x=26208.0, xmax=1360
# Y wrong!!!: y=2897.0, ymax=1024
# X wrong!!!: x=26301.0, xmax=1360
# Y wrong!!!: y=2915.0, ymax=1024
# X wrong!!!: x=26384.0, xmax=1360
# Y wrong!!!: y=2936.0, ymax=1024
# X wrong!!!: x=26458.0, xmax=1360
# Y wrong!!!: y=2957.0, ymax=1024
# X wrong!!!: x=26521.0, xmax=1360
# Y wrong!!!: y=2980.0, ymax=1024
# X wrong!!!: x=26573.0, xmax=1360
# Y wrong!!!: y=3003.0, ymax=1024
# X wrong!!!: x=26615.0, xmax=1360
# Y wrong!!!: y=3027.0, ymax=1024
# X wrong!!!: x=26644.0, xmax=1360
# Y wrong!!!: y=3052.0, ymax=1024
# X wrong!!!: x=26662.0, xmax=1360
# Y wrong!!!: y=3078.0, ymax=1024
# X wrong!!!: x=26668.0, xmax=1360
# Y wrong!!!: y=3103.0, ymax=1024
# X wrong!!!: x=46945.0, xmax=1360
# Y wrong!!!: y=2722.0, ymax=1024
# X wrong!!!: x=46938.0, xmax=1360
# Y wrong!!!: y=2741.0, ymax=1024
# X wrong!!!: x=46919.0, xmax=1360
# Y wrong!!!: y=2760.0, ymax=1024
# X wrong!!!: x=46886.0, xmax=1360
# Y wrong!!!: y=2779.0, ymax=1024
# X wrong!!!: x=46841.0, xmax=1360
# Y wrong!!!: y=2797.0, ymax=1024
# X wrong!!!: x=46783.0, xmax=1360
# Y wrong!!!: y=2815.0, ymax=1024
# X wrong!!!: x=46713.0, xmax=1360
# Y wrong!!!: y=2832.0, ymax=1024
# X wrong!!!: x=46632.0, xmax=1360
# Y wrong!!!: y=2848.0, ymax=1024
# X wrong!!!: x=46540.0, xmax=1360
# Y wrong!!!: y=2863.0, ymax=1024
# X wrong!!!: x=46438.0, xmax=1360
# Y wrong!!!: y=2877.0, ymax=1024
# X wrong!!!: x=46326.0, xmax=1360
# Y wrong!!!: y=2890.0, ymax=1024
# X wrong!!!: x=46206.0, xmax=1360
# Y wrong!!!: y=2901.0, ymax=1024
# X wrong!!!: x=46079.0, xmax=1360
# Y wrong!!!: y=2912.0, ymax=1024
# X wrong!!!: x=45945.0, xmax=1360
# Y wrong!!!: y=2920.0, ymax=1024
# X wrong!!!: x=45805.0, xmax=1360
# Y wrong!!!: y=2928.0, ymax=1024
# X wrong!!!: x=45661.0, xmax=1360
# Y wrong!!!: y=2934.0, ymax=1024
# X wrong!!!: x=45514.0, xmax=1360
# Y wrong!!!: y=2938.0, ymax=1024
# X wrong!!!: x=45364.0, xmax=1360
# Y wrong!!!: y=2940.0, ymax=1024
# X wrong!!!: x=45213.0, xmax=1360
# Y wrong!!!: y=2941.0, ymax=1024
# X wrong!!!: x=45062.0, xmax=1360
# Y wrong!!!: y=2940.0, ymax=1024
# X wrong!!!: x=44912.0, xmax=1360
# Y wrong!!!: y=2938.0, ymax=1024
# X wrong!!!: x=44765.0, xmax=1360
# Y wrong!!!: y=2934.0, ymax=1024
# X wrong!!!: x=44621.0, xmax=1360
# Y wrong!!!: y=2928.0, ymax=1024
# X wrong!!!: x=44481.0, xmax=1360
# Y wrong!!!: y=2920.0, ymax=1024
# X wrong!!!: x=44347.0, xmax=1360
# Y wrong!!!: y=2912.0, ymax=1024
# X wrong!!!: x=44220.0, xmax=1360
# Y wrong!!!: y=2901.0, ymax=1024
# X wrong!!!: x=44100.0, xmax=1360
# Y wrong!!!: y=2890.0, ymax=1024
# X wrong!!!: x=43988.0, xmax=1360
# Y wrong!!!: y=2877.0, ymax=1024
# X wrong!!!: x=43886.0, xmax=1360
# Y wrong!!!: y=2863.0, ymax=1024
# X wrong!!!: x=43794.0, xmax=1360
# Y wrong!!!: y=2848.0, ymax=1024
# X wrong!!!: x=43713.0, xmax=1360
# Y wrong!!!: y=2832.0, ymax=1024
# X wrong!!!: x=43643.0, xmax=1360
# Y wrong!!!: y=2815.0, ymax=1024
# X wrong!!!: x=43585.0, xmax=1360
# Y wrong!!!: y=2797.0, ymax=1024
# X wrong!!!: x=43540.0, xmax=1360
# Y wrong!!!: y=2779.0, ymax=1024
# X wrong!!!: x=43507.0, xmax=1360
# Y wrong!!!: y=2760.0, ymax=1024
# X wrong!!!: x=43488.0, xmax=1360
# Y wrong!!!: y=2741.0, ymax=1024
# X wrong!!!: x=43481.0, xmax=1360
# Y wrong!!!: y=2722.0, ymax=1024
# X wrong!!!: x=43488.0, xmax=1360
# Y wrong!!!: y=2703.0, ymax=1024
# X wrong!!!: x=43507.0, xmax=1360
# Y wrong!!!: y=2684.0, ymax=1024
# X wrong!!!: x=43540.0, xmax=1360
# Y wrong!!!: y=2665.0, ymax=1024
# X wrong!!!: x=43585.0, xmax=1360
# Y wrong!!!: y=2647.0, ymax=1024
# X wrong!!!: x=43643.0, xmax=1360
# Y wrong!!!: y=2629.0, ymax=1024
# X wrong!!!: x=43713.0, xmax=1360
# Y wrong!!!: y=2612.0, ymax=1024
# X wrong!!!: x=43794.0, xmax=1360
# Y wrong!!!: y=2596.0, ymax=1024
# X wrong!!!: x=43886.0, xmax=1360
# Y wrong!!!: y=2581.0, ymax=1024
# X wrong!!!: x=43988.0, xmax=1360
# Y wrong!!!: y=2567.0, ymax=1024
# X wrong!!!: x=44100.0, xmax=1360
# Y wrong!!!: y=2554.0, ymax=1024
# X wrong!!!: x=44220.0, xmax=1360
# Y wrong!!!: y=2543.0, ymax=1024
# X wrong!!!: x=44347.0, xmax=1360
# Y wrong!!!: y=2532.0, ymax=1024
# X wrong!!!: x=44481.0, xmax=1360
# Y wrong!!!: y=2524.0, ymax=1024
# X wrong!!!: x=44621.0, xmax=1360
# Y wrong!!!: y=2516.0, ymax=1024
# X wrong!!!: x=44765.0, xmax=1360
# Y wrong!!!: y=2510.0, ymax=1024
# X wrong!!!: x=44912.0, xmax=1360
# Y wrong!!!: y=2506.0, ymax=1024
# X wrong!!!: x=45062.0, xmax=1360
# Y wrong!!!: y=2504.0, ymax=1024
# X wrong!!!: x=45213.0, xmax=1360
# Y wrong!!!: y=2503.0, ymax=1024
# X wrong!!!: x=45364.0, xmax=1360
# Y wrong!!!: y=2504.0, ymax=1024
# X wrong!!!: x=45514.0, xmax=1360
# Y wrong!!!: y=2506.0, ymax=1024
# X wrong!!!: x=45661.0, xmax=1360
# Y wrong!!!: y=2510.0, ymax=1024
# X wrong!!!: x=45805.0, xmax=1360
# Y wrong!!!: y=2516.0, ymax=1024
# X wrong!!!: x=45945.0, xmax=1360
# Y wrong!!!: y=2524.0, ymax=1024
# X wrong!!!: x=46079.0, xmax=1360
# Y wrong!!!: y=2532.0, ymax=1024
# X wrong!!!: x=46206.0, xmax=1360
# Y wrong!!!: y=2543.0, ymax=1024
# X wrong!!!: x=46326.0, xmax=1360
# Y wrong!!!: y=2554.0, ymax=1024
# X wrong!!!: x=46438.0, xmax=1360
# Y wrong!!!: y=2567.0, ymax=1024
# X wrong!!!: x=46540.0, xmax=1360
# Y wrong!!!: y=2581.0, ymax=1024
# X wrong!!!: x=46632.0, xmax=1360
# Y wrong!!!: y=2596.0, ymax=1024
# X wrong!!!: x=46713.0, xmax=1360
# Y wrong!!!: y=2612.0, ymax=1024
# X wrong!!!: x=46783.0, xmax=1360
# Y wrong!!!: y=2629.0, ymax=1024
# X wrong!!!: x=46841.0, xmax=1360
# Y wrong!!!: y=2647.0, ymax=1024
# X wrong!!!: x=46886.0, xmax=1360
# Y wrong!!!: y=2665.0, ymax=1024
# X wrong!!!: x=46919.0, xmax=1360
# Y wrong!!!: y=2684.0, ymax=1024
# X wrong!!!: x=46938.0, xmax=1360
# Y wrong!!!: y=2703.0, ymax=1024
# X wrong!!!: x=46945.0, xmax=1360
# Y wrong!!!: y=2722.0, ymax=1024
# X wrong!!!: x=63195.0, xmax=1360
# Y wrong!!!: y=2846.0, ymax=1024
# X wrong!!!: x=63188.0, xmax=1360
# Y wrong!!!: y=2865.0, ymax=1024
# X wrong!!!: x=63169.0, xmax=1360
# Y wrong!!!: y=2883.0, ymax=1024
# X wrong!!!: x=63136.0, xmax=1360
# Y wrong!!!: y=2901.0, ymax=1024
# X wrong!!!: x=63091.0, xmax=1360
# Y wrong!!!: y=2919.0, ymax=1024
# X wrong!!!: x=63033.0, xmax=1360
# Y wrong!!!: y=2936.0, ymax=1024
# X wrong!!!: x=62963.0, xmax=1360
# Y wrong!!!: y=2953.0, ymax=1024
# X wrong!!!: x=62882.0, xmax=1360
# Y wrong!!!: y=2969.0, ymax=1024
# X wrong!!!: x=62790.0, xmax=1360
# Y wrong!!!: y=2984.0, ymax=1024
# X wrong!!!: x=62688.0, xmax=1360
# Y wrong!!!: y=2997.0, ymax=1024
# X wrong!!!: x=62577.0, xmax=1360
# Y wrong!!!: y=3010.0, ymax=1024
# X wrong!!!: x=62457.0, xmax=1360
# Y wrong!!!: y=3021.0, ymax=1024
# X wrong!!!: x=62330.0, xmax=1360
# Y wrong!!!: y=3031.0, ymax=1024
# X wrong!!!: x=62196.0, xmax=1360
# Y wrong!!!: y=3040.0, ymax=1024
# X wrong!!!: x=62056.0, xmax=1360
# Y wrong!!!: y=3047.0, ymax=1024
# X wrong!!!: x=61912.0, xmax=1360
# Y wrong!!!: y=3053.0, ymax=1024
# X wrong!!!: x=61765.0, xmax=1360
# Y wrong!!!: y=3057.0, ymax=1024
# X wrong!!!: x=61615.0, xmax=1360
# Y wrong!!!: y=3059.0, ymax=1024
# X wrong!!!: x=61464.0, xmax=1360
# Y wrong!!!: y=3060.0, ymax=1024
# X wrong!!!: x=61313.0, xmax=1360
# Y wrong!!!: y=3059.0, ymax=1024
# X wrong!!!: x=61163.0, xmax=1360
# Y wrong!!!: y=3057.0, ymax=1024
# X wrong!!!: x=61016.0, xmax=1360
# Y wrong!!!: y=3053.0, ymax=1024
# X wrong!!!: x=60872.0, xmax=1360
# Y wrong!!!: y=3047.0, ymax=1024
# X wrong!!!: x=60732.0, xmax=1360
# Y wrong!!!: y=3040.0, ymax=1024
# X wrong!!!: x=60598.0, xmax=1360
# Y wrong!!!: y=3031.0, ymax=1024
# X wrong!!!: x=60471.0, xmax=1360
# Y wrong!!!: y=3021.0, ymax=1024
# X wrong!!!: x=60351.0, xmax=1360
# Y wrong!!!: y=3010.0, ymax=1024
# X wrong!!!: x=60240.0, xmax=1360
# Y wrong!!!: y=2997.0, ymax=1024
# X wrong!!!: x=60138.0, xmax=1360
# Y wrong!!!: y=2984.0, ymax=1024
# X wrong!!!: x=60046.0, xmax=1360
# Y wrong!!!: y=2969.0, ymax=1024
# X wrong!!!: x=59965.0, xmax=1360
# Y wrong!!!: y=2953.0, ymax=1024
# X wrong!!!: x=59895.0, xmax=1360
# Y wrong!!!: y=2936.0, ymax=1024
# X wrong!!!: x=59837.0, xmax=1360
# Y wrong!!!: y=2919.0, ymax=1024
# X wrong!!!: x=59792.0, xmax=1360
# Y wrong!!!: y=2901.0, ymax=1024
# X wrong!!!: x=59759.0, xmax=1360
# Y wrong!!!: y=2883.0, ymax=1024
# X wrong!!!: x=59740.0, xmax=1360
# Y wrong!!!: y=2865.0, ymax=1024
# X wrong!!!: x=59733.0, xmax=1360
# Y wrong!!!: y=2846.0, ymax=1024
# X wrong!!!: x=59740.0, xmax=1360
# Y wrong!!!: y=2827.0, ymax=1024
# X wrong!!!: x=59759.0, xmax=1360
# Y wrong!!!: y=2809.0, ymax=1024
# X wrong!!!: x=59792.0, xmax=1360
# Y wrong!!!: y=2791.0, ymax=1024
# X wrong!!!: x=59837.0, xmax=1360
# Y wrong!!!: y=2773.0, ymax=1024
# X wrong!!!: x=59895.0, xmax=1360
# Y wrong!!!: y=2756.0, ymax=1024
# X wrong!!!: x=59965.0, xmax=1360
# Y wrong!!!: y=2739.0, ymax=1024
# X wrong!!!: x=60046.0, xmax=1360
# Y wrong!!!: y=2723.0, ymax=1024
# X wrong!!!: x=60138.0, xmax=1360
# Y wrong!!!: y=2708.0, ymax=1024
# X wrong!!!: x=60240.0, xmax=1360
# Y wrong!!!: y=2695.0, ymax=1024
# X wrong!!!: x=60351.0, xmax=1360
# Y wrong!!!: y=2682.0, ymax=1024
# X wrong!!!: x=60471.0, xmax=1360
# Y wrong!!!: y=2671.0, ymax=1024
# X wrong!!!: x=60598.0, xmax=1360
# Y wrong!!!: y=2661.0, ymax=1024
# X wrong!!!: x=60732.0, xmax=1360
# Y wrong!!!: y=2652.0, ymax=1024
# X wrong!!!: x=60872.0, xmax=1360
# Y wrong!!!: y=2645.0, ymax=1024
# X wrong!!!: x=61016.0, xmax=1360
# Y wrong!!!: y=2639.0, ymax=1024
# X wrong!!!: x=61163.0, xmax=1360
# Y wrong!!!: y=2635.0, ymax=1024
# X wrong!!!: x=61313.0, xmax=1360
# Y wrong!!!: y=2633.0, ymax=1024
# X wrong!!!: x=61464.0, xmax=1360
# Y wrong!!!: y=2632.0, ymax=1024
# X wrong!!!: x=61615.0, xmax=1360
# Y wrong!!!: y=2633.0, ymax=1024
# X wrong!!!: x=61765.0, xmax=1360
# Y wrong!!!: y=2635.0, ymax=1024
# X wrong!!!: x=61912.0, xmax=1360
# Y wrong!!!: y=2639.0, ymax=1024
# X wrong!!!: x=62056.0, xmax=1360
# Y wrong!!!: y=2645.0, ymax=1024
# X wrong!!!: x=62196.0, xmax=1360
# Y wrong!!!: y=2652.0, ymax=1024
# X wrong!!!: x=62330.0, xmax=1360
# Y wrong!!!: y=2661.0, ymax=1024
# X wrong!!!: x=62457.0, xmax=1360
# Y wrong!!!: y=2671.0, ymax=1024
# X wrong!!!: x=62577.0, xmax=1360
# Y wrong!!!: y=2682.0, ymax=1024
# X wrong!!!: x=62688.0, xmax=1360
# Y wrong!!!: y=2695.0, ymax=1024
# X wrong!!!: x=62790.0, xmax=1360
# Y wrong!!!: y=2708.0, ymax=1024
# X wrong!!!: x=62882.0, xmax=1360
# Y wrong!!!: y=2723.0, ymax=1024
# X wrong!!!: x=62963.0, xmax=1360
# Y wrong!!!: y=2739.0, ymax=1024
# X wrong!!!: x=63033.0, xmax=1360
# Y wrong!!!: y=2756.0, ymax=1024
# X wrong!!!: x=63091.0, xmax=1360
# Y wrong!!!: y=2773.0, ymax=1024
# X wrong!!!: x=63136.0, xmax=1360
# Y wrong!!!: y=2791.0, ymax=1024
# X wrong!!!: x=63169.0, xmax=1360
# Y wrong!!!: y=2809.0, ymax=1024
# X wrong!!!: x=63188.0, xmax=1360
# Y wrong!!!: y=2827.0, ymax=1024
# X wrong!!!: x=63195.0, xmax=1360
# Y wrong!!!: y=2846.0, ymax=1024
# X wrong!!!: x=82737.0, xmax=1360
# Y wrong!!!: y=3050.0, ymax=1024
# X wrong!!!: x=82731.0, xmax=1360
# Y wrong!!!: y=3064.0, ymax=1024
# X wrong!!!: x=82715.0, xmax=1360
# Y wrong!!!: y=3078.0, ymax=1024
# X wrong!!!: x=82688.0, xmax=1360
# Y wrong!!!: y=3091.0, ymax=1024
# X wrong!!!: x=82651.0, xmax=1360
# Y wrong!!!: y=3103.0, ymax=1024
# X wrong!!!: x=82604.0, xmax=1360
# Y wrong!!!: y=3114.0, ymax=1024
# X wrong!!!: x=82548.0, xmax=1360
# Y wrong!!!: y=3124.0, ymax=1024
# X wrong!!!: x=82483.0, xmax=1360
# Y wrong!!!: y=3133.0, ymax=1024
# X wrong!!!: x=82409.0, xmax=1360
# Y wrong!!!: y=3141.0, ymax=1024
# X wrong!!!: x=82327.0, xmax=1360
# Y wrong!!!: y=3147.0, ymax=1024
# X wrong!!!: x=82238.0, xmax=1360
# Y wrong!!!: y=3152.0, ymax=1024
# X wrong!!!: x=82142.0, xmax=1360
# Y wrong!!!: y=3156.0, ymax=1024
# X wrong!!!: x=82040.0, xmax=1360
# Y wrong!!!: y=3159.0, ymax=1024
# X wrong!!!: x=81933.0, xmax=1360
# Y wrong!!!: y=3160.0, ymax=1024
# X wrong!!!: x=81822.0, xmax=1360
# Y wrong!!!: y=3159.0, ymax=1024
# X wrong!!!: x=81707.0, xmax=1360
# Y wrong!!!: y=3158.0, ymax=1024
# X wrong!!!: x=81590.0, xmax=1360
# Y wrong!!!: y=3155.0, ymax=1024
# X wrong!!!: x=81470.0, xmax=1360
# Y wrong!!!: y=3150.0, ymax=1024
# X wrong!!!: x=81350.0, xmax=1360
# Y wrong!!!: y=3145.0, ymax=1024
# X wrong!!!: x=81230.0, xmax=1360
# Y wrong!!!: y=3138.0, ymax=1024
# X wrong!!!: x=81111.0, xmax=1360
# Y wrong!!!: y=3130.0, ymax=1024
# X wrong!!!: x=80994.0, xmax=1360
# Y wrong!!!: y=3120.0, ymax=1024
# X wrong!!!: x=80879.0, xmax=1360
# Y wrong!!!: y=3110.0, ymax=1024
# X wrong!!!: x=80769.0, xmax=1360
# Y wrong!!!: y=3099.0, ymax=1024
# X wrong!!!: x=80662.0, xmax=1360
# Y wrong!!!: y=3086.0, ymax=1024
# X wrong!!!: x=80561.0, xmax=1360
# Y wrong!!!: y=3073.0, ymax=1024
# X wrong!!!: x=80466.0, xmax=1360
# Y wrong!!!: y=3059.0, ymax=1024
# X wrong!!!: x=80378.0, xmax=1360
# Y wrong!!!: y=3045.0, ymax=1024
# X wrong!!!: x=80298.0, xmax=1360
# Y wrong!!!: y=3030.0, ymax=1024
# X wrong!!!: x=80225.0, xmax=1360
# Y wrong!!!: y=3014.0, ymax=1024
# X wrong!!!: x=80161.0, xmax=1360
# Y wrong!!!: y=2999.0, ymax=1024
# X wrong!!!: x=80106.0, xmax=1360
# Y wrong!!!: y=2983.0, ymax=1024
# X wrong!!!: x=80061.0, xmax=1360
# Y wrong!!!: y=2967.0, ymax=1024
# X wrong!!!: x=80026.0, xmax=1360
# Y wrong!!!: y=2951.0, ymax=1024
# X wrong!!!: x=80000.0, xmax=1360
# Y wrong!!!: y=2936.0, ymax=1024
# X wrong!!!: x=79985.0, xmax=1360
# Y wrong!!!: y=2921.0, ymax=1024
# X wrong!!!: x=79981.0, xmax=1360
# Y wrong!!!: y=2906.0, ymax=1024
# X wrong!!!: x=79987.0, xmax=1360
# Y wrong!!!: y=2892.0, ymax=1024
# X wrong!!!: x=80003.0, xmax=1360
# Y wrong!!!: y=2878.0, ymax=1024
# X wrong!!!: x=80030.0, xmax=1360
# Y wrong!!!: y=2865.0, ymax=1024
# X wrong!!!: x=80067.0, xmax=1360
# Y wrong!!!: y=2853.0, ymax=1024
# X wrong!!!: x=80114.0, xmax=1360
# Y wrong!!!: y=2842.0, ymax=1024
# X wrong!!!: x=80170.0, xmax=1360
# Y wrong!!!: y=2832.0, ymax=1024
# X wrong!!!: x=80235.0, xmax=1360
# Y wrong!!!: y=2823.0, ymax=1024
# X wrong!!!: x=80309.0, xmax=1360
# Y wrong!!!: y=2815.0, ymax=1024
# X wrong!!!: x=80391.0, xmax=1360
# Y wrong!!!: y=2809.0, ymax=1024
# X wrong!!!: x=80480.0, xmax=1360
# Y wrong!!!: y=2804.0, ymax=1024
# X wrong!!!: x=80576.0, xmax=1360
# Y wrong!!!: y=2800.0, ymax=1024
# X wrong!!!: x=80678.0, xmax=1360
# Y wrong!!!: y=2797.0, ymax=1024
# X wrong!!!: x=80785.0, xmax=1360
# Y wrong!!!: y=2796.0, ymax=1024
# X wrong!!!: x=80896.0, xmax=1360
# Y wrong!!!: y=2797.0, ymax=1024
# X wrong!!!: x=81011.0, xmax=1360
# Y wrong!!!: y=2798.0, ymax=1024
# X wrong!!!: x=81128.0, xmax=1360
# Y wrong!!!: y=2801.0, ymax=1024
# X wrong!!!: x=81248.0, xmax=1360
# Y wrong!!!: y=2806.0, ymax=1024
# X wrong!!!: x=81368.0, xmax=1360
# Y wrong!!!: y=2811.0, ymax=1024
# X wrong!!!: x=81488.0, xmax=1360
# Y wrong!!!: y=2818.0, ymax=1024
# X wrong!!!: x=81607.0, xmax=1360
# Y wrong!!!: y=2826.0, ymax=1024
# X wrong!!!: x=81724.0, xmax=1360
# Y wrong!!!: y=2836.0, ymax=1024
# X wrong!!!: x=81839.0, xmax=1360
# Y wrong!!!: y=2846.0, ymax=1024
# X wrong!!!: x=81949.0, xmax=1360
# Y wrong!!!: y=2857.0, ymax=1024
# X wrong!!!: x=82056.0, xmax=1360
# Y wrong!!!: y=2870.0, ymax=1024
# X wrong!!!: x=82157.0, xmax=1360
# Y wrong!!!: y=2883.0, ymax=1024
# X wrong!!!: x=82252.0, xmax=1360
# Y wrong!!!: y=2897.0, ymax=1024
# X wrong!!!: x=82340.0, xmax=1360
# Y wrong!!!: y=2911.0, ymax=1024
# X wrong!!!: x=82420.0, xmax=1360
# Y wrong!!!: y=2926.0, ymax=1024
# X wrong!!!: x=82493.0, xmax=1360
# Y wrong!!!: y=2942.0, ymax=1024
# X wrong!!!: x=82557.0, xmax=1360
# Y wrong!!!: y=2957.0, ymax=1024
# X wrong!!!: x=82612.0, xmax=1360
# Y wrong!!!: y=2973.0, ymax=1024
# X wrong!!!: x=82657.0, xmax=1360
# Y wrong!!!: y=2989.0, ymax=1024
# X wrong!!!: x=82692.0, xmax=1360
# Y wrong!!!: y=3005.0, ymax=1024
# X wrong!!!: x=82718.0, xmax=1360
# Y wrong!!!: y=3020.0, ymax=1024
# X wrong!!!: x=82733.0, xmax=1360
# Y wrong!!!: y=3035.0, ymax=1024
# X wrong!!!: x=82737.0, xmax=1360
# Y wrong!!!: y=3050.0, ymax=1024
# X wrong!!!: x=108846.0, xmax=1360
# Y wrong!!!: y=3037.0, ymax=1024
# X wrong!!!: x=108839.0, xmax=1360
# Y wrong!!!: y=3055.0, ymax=1024
# X wrong!!!: x=108817.0, xmax=1360
# Y wrong!!!: y=3073.0, ymax=1024
# X wrong!!!: x=108780.0, xmax=1360
# Y wrong!!!: y=3092.0, ymax=1024
# X wrong!!!: x=108727.0, xmax=1360
# Y wrong!!!: y=3112.0, ymax=1024
# X wrong!!!: x=108660.0, xmax=1360
# Y wrong!!!: y=3132.0, ymax=1024
# X wrong!!!: x=108579.0, xmax=1360
# Y wrong!!!: y=3153.0, ymax=1024
# X wrong!!!: x=108484.0, xmax=1360
# Y wrong!!!: y=3174.0, ymax=1024
# X wrong!!!: x=108377.0, xmax=1360
# Y wrong!!!: y=3195.0, ymax=1024
# X wrong!!!: x=108257.0, xmax=1360
# Y wrong!!!: y=3216.0, ymax=1024
# X wrong!!!: x=108127.0, xmax=1360
# Y wrong!!!: y=3236.0, ymax=1024
# X wrong!!!: x=107986.0, xmax=1360
# Y wrong!!!: y=3257.0, ymax=1024
# X wrong!!!: x=107836.0, xmax=1360
# Y wrong!!!: y=3276.0, ymax=1024
# X wrong!!!: x=107679.0, xmax=1360
# Y wrong!!!: y=3295.0, ymax=1024
# X wrong!!!: x=107514.0, xmax=1360
# Y wrong!!!: y=3313.0, ymax=1024
# X wrong!!!: x=107345.0, xmax=1360
# Y wrong!!!: y=3330.0, ymax=1024
# X wrong!!!: x=107171.0, xmax=1360
# Y wrong!!!: y=3346.0, ymax=1024
# X wrong!!!: x=106995.0, xmax=1360
# Y wrong!!!: y=3360.0, ymax=1024
# X wrong!!!: x=106817.0, xmax=1360
# Y wrong!!!: y=3374.0, ymax=1024
# X wrong!!!: x=106638.0, xmax=1360
# Y wrong!!!: y=3385.0, ymax=1024
# X wrong!!!: x=106462.0, xmax=1360
# Y wrong!!!: y=3395.0, ymax=1024
# X wrong!!!: x=106287.0, xmax=1360
# Y wrong!!!: y=3404.0, ymax=1024
# X wrong!!!: x=106117.0, xmax=1360
# Y wrong!!!: y=3411.0, ymax=1024
# X wrong!!!: x=105952.0, xmax=1360
# Y wrong!!!: y=3416.0, ymax=1024
# X wrong!!!: x=105793.0, xmax=1360
# Y wrong!!!: y=3419.0, ymax=1024
# X wrong!!!: x=105642.0, xmax=1360
# Y wrong!!!: y=3420.0, ymax=1024
# X wrong!!!: x=105500.0, xmax=1360
# Y wrong!!!: y=3420.0, ymax=1024
# X wrong!!!: x=105368.0, xmax=1360
# Y wrong!!!: y=3418.0, ymax=1024
# X wrong!!!: x=105247.0, xmax=1360
# Y wrong!!!: y=3414.0, ymax=1024
# X wrong!!!: x=105137.0, xmax=1360
# Y wrong!!!: y=3408.0, ymax=1024
# X wrong!!!: x=105040.0, xmax=1360
# Y wrong!!!: y=3400.0, ymax=1024
# X wrong!!!: x=104957.0, xmax=1360
# Y wrong!!!: y=3391.0, ymax=1024
# X wrong!!!: x=104888.0, xmax=1360
# Y wrong!!!: y=3380.0, ymax=1024
# X wrong!!!: x=104833.0, xmax=1360
# Y wrong!!!: y=3368.0, ymax=1024
# X wrong!!!: x=104793.0, xmax=1360
# Y wrong!!!: y=3354.0, ymax=1024
# X wrong!!!: x=104769.0, xmax=1360
# Y wrong!!!: y=3339.0, ymax=1024
# X wrong!!!: x=104760.0, xmax=1360
# Y wrong!!!: y=3323.0, ymax=1024
# X wrong!!!: x=104767.0, xmax=1360
# Y wrong!!!: y=3305.0, ymax=1024
# X wrong!!!: x=104789.0, xmax=1360
# Y wrong!!!: y=3287.0, ymax=1024
# X wrong!!!: x=104826.0, xmax=1360
# Y wrong!!!: y=3268.0, ymax=1024
# X wrong!!!: x=104879.0, xmax=1360
# Y wrong!!!: y=3248.0, ymax=1024
# X wrong!!!: x=104946.0, xmax=1360
# Y wrong!!!: y=3228.0, ymax=1024
# X wrong!!!: x=105027.0, xmax=1360
# Y wrong!!!: y=3207.0, ymax=1024
# X wrong!!!: x=105122.0, xmax=1360
# Y wrong!!!: y=3186.0, ymax=1024
# X wrong!!!: x=105229.0, xmax=1360
# Y wrong!!!: y=3165.0, ymax=1024
# X wrong!!!: x=105349.0, xmax=1360
# Y wrong!!!: y=3144.0, ymax=1024
# X wrong!!!: x=105479.0, xmax=1360
# Y wrong!!!: y=3124.0, ymax=1024
# X wrong!!!: x=105620.0, xmax=1360
# Y wrong!!!: y=3103.0, ymax=1024
# X wrong!!!: x=105770.0, xmax=1360
# Y wrong!!!: y=3084.0, ymax=1024
# X wrong!!!: x=105927.0, xmax=1360
# Y wrong!!!: y=3065.0, ymax=1024
# X wrong!!!: x=106092.0, xmax=1360
# Y wrong!!!: y=3047.0, ymax=1024
# X wrong!!!: x=106261.0, xmax=1360
# Y wrong!!!: y=3030.0, ymax=1024
# X wrong!!!: x=106435.0, xmax=1360
# Y wrong!!!: y=3014.0, ymax=1024
# X wrong!!!: x=106611.0, xmax=1360
# Y wrong!!!: y=3000.0, ymax=1024
# X wrong!!!: x=106789.0, xmax=1360
# Y wrong!!!: y=2986.0, ymax=1024
# X wrong!!!: x=106968.0, xmax=1360
# Y wrong!!!: y=2975.0, ymax=1024
# X wrong!!!: x=107144.0, xmax=1360
# Y wrong!!!: y=2965.0, ymax=1024
# X wrong!!!: x=107319.0, xmax=1360
# Y wrong!!!: y=2956.0, ymax=1024
# X wrong!!!: x=107489.0, xmax=1360
# Y wrong!!!: y=2949.0, ymax=1024
# X wrong!!!: x=107654.0, xmax=1360
# Y wrong!!!: y=2944.0, ymax=1024
# X wrong!!!: x=107813.0, xmax=1360
# Y wrong!!!: y=2941.0, ymax=1024
# X wrong!!!: x=107964.0, xmax=1360
# Y wrong!!!: y=2940.0, ymax=1024
# X wrong!!!: x=108106.0, xmax=1360
# Y wrong!!!: y=2940.0, ymax=1024
# X wrong!!!: x=108238.0, xmax=1360
# Y wrong!!!: y=2942.0, ymax=1024
# X wrong!!!: x=108359.0, xmax=1360
# Y wrong!!!: y=2946.0, ymax=1024
# X wrong!!!: x=108469.0, xmax=1360
# Y wrong!!!: y=2952.0, ymax=1024
# X wrong!!!: x=108566.0, xmax=1360
# Y wrong!!!: y=2960.0, ymax=1024
# X wrong!!!: x=108649.0, xmax=1360
# Y wrong!!!: y=2969.0, ymax=1024
# X wrong!!!: x=108718.0, xmax=1360
# Y wrong!!!: y=2980.0, ymax=1024
# X wrong!!!: x=108773.0, xmax=1360
# Y wrong!!!: y=2992.0, ymax=1024
# X wrong!!!: x=108813.0, xmax=1360
# Y wrong!!!: y=3006.0, ymax=1024
# X wrong!!!: x=108837.0, xmax=1360
# Y wrong!!!: y=3021.0, ymax=1024
# X wrong!!!: x=108846.0, xmax=1360
# Y wrong!!!: y=3037.0, ymax=1024
# X wrong!!!: x=131719.0, xmax=1360
# Y wrong!!!: y=17957.0, ymax=1024
# X wrong!!!: x=131713.0, xmax=1360
# Y wrong!!!: y=17983.0, ymax=1024
# X wrong!!!: x=131694.0, xmax=1360
# Y wrong!!!: y=18008.0, ymax=1024
# X wrong!!!: x=131662.0, xmax=1360
# Y wrong!!!: y=18033.0, ymax=1024
# X wrong!!!: x=131618.0, xmax=1360
# Y wrong!!!: y=18058.0, ymax=1024
# X wrong!!!: x=131562.0, xmax=1360
# Y wrong!!!: y=18081.0, ymax=1024
# X wrong!!!: x=131495.0, xmax=1360
# Y wrong!!!: y=18104.0, ymax=1024
# X wrong!!!: x=131417.0, xmax=1360
# Y wrong!!!: y=18126.0, ymax=1024
# X wrong!!!: x=131328.0, xmax=1360
# Y wrong!!!: y=18146.0, ymax=1024
# X wrong!!!: x=131230.0, xmax=1360
# Y wrong!!!: y=18165.0, ymax=1024
# X wrong!!!: x=131122.0, xmax=1360
# Y wrong!!!: y=18182.0, ymax=1024
# X wrong!!!: x=131006.0, xmax=1360
# Y wrong!!!: y=18198.0, ymax=1024
# X wrong!!!: x=130884.0, xmax=1360
# Y wrong!!!: y=18212.0, ymax=1024
# X wrong!!!: x=130754.0, xmax=1360
# Y wrong!!!: y=18223.0, ymax=1024
# X wrong!!!: x=130620.0, xmax=1360
# Y wrong!!!: y=18233.0, ymax=1024
# X wrong!!!: x=130480.0, xmax=1360
# Y wrong!!!: y=18241.0, ymax=1024
# X wrong!!!: x=130338.0, xmax=1360
# Y wrong!!!: y=18247.0, ymax=1024
# X wrong!!!: x=130194.0, xmax=1360
# Y wrong!!!: y=18250.0, ymax=1024
# X wrong!!!: x=130048.0, xmax=1360
# Y wrong!!!: y=18251.0, ymax=1024
# X wrong!!!: x=129902.0, xmax=1360
# Y wrong!!!: y=18250.0, ymax=1024
# X wrong!!!: x=129758.0, xmax=1360
# Y wrong!!!: y=18247.0, ymax=1024
# X wrong!!!: x=129616.0, xmax=1360
# Y wrong!!!: y=18241.0, ymax=1024
# X wrong!!!: x=129476.0, xmax=1360
# Y wrong!!!: y=18233.0, ymax=1024
# X wrong!!!: x=129342.0, xmax=1360
# Y wrong!!!: y=18223.0, ymax=1024
# X wrong!!!: x=129212.0, xmax=1360
# Y wrong!!!: y=18212.0, ymax=1024
# X wrong!!!: x=129090.0, xmax=1360
# Y wrong!!!: y=18198.0, ymax=1024
# X wrong!!!: x=128974.0, xmax=1360
# Y wrong!!!: y=18182.0, ymax=1024
# X wrong!!!: x=128866.0, xmax=1360
# Y wrong!!!: y=18165.0, ymax=1024
# X wrong!!!: x=128768.0, xmax=1360
# Y wrong!!!: y=18146.0, ymax=1024
# X wrong!!!: x=128679.0, xmax=1360
# Y wrong!!!: y=18126.0, ymax=1024
# X wrong!!!: x=128601.0, xmax=1360
# Y wrong!!!: y=18104.0, ymax=1024
# X wrong!!!: x=128534.0, xmax=1360
# Y wrong!!!: y=18081.0, ymax=1024
# X wrong!!!: x=128478.0, xmax=1360
# Y wrong!!!: y=18058.0, ymax=1024
# X wrong!!!: x=128434.0, xmax=1360
# Y wrong!!!: y=18033.0, ymax=1024
# X wrong!!!: x=128402.0, xmax=1360
# Y wrong!!!: y=18008.0, ymax=1024
# X wrong!!!: x=128383.0, xmax=1360
# Y wrong!!!: y=17983.0, ymax=1024
# X wrong!!!: x=128377.0, xmax=1360
# Y wrong!!!: y=17957.0, ymax=1024
# X wrong!!!: x=128383.0, xmax=1360
# Y wrong!!!: y=17931.0, ymax=1024
# X wrong!!!: x=128402.0, xmax=1360
# Y wrong!!!: y=17906.0, ymax=1024
# X wrong!!!: x=128434.0, xmax=1360
# Y wrong!!!: y=17881.0, ymax=1024
# X wrong!!!: x=128478.0, xmax=1360
# Y wrong!!!: y=17856.0, ymax=1024
# X wrong!!!: x=128534.0, xmax=1360
# Y wrong!!!: y=17833.0, ymax=1024
# X wrong!!!: x=128601.0, xmax=1360
# Y wrong!!!: y=17810.0, ymax=1024
# X wrong!!!: x=128679.0, xmax=1360
# Y wrong!!!: y=17788.0, ymax=1024
# X wrong!!!: x=128768.0, xmax=1360
# Y wrong!!!: y=17768.0, ymax=1024
# X wrong!!!: x=128866.0, xmax=1360
# Y wrong!!!: y=17749.0, ymax=1024
# X wrong!!!: x=128974.0, xmax=1360
# Y wrong!!!: y=17732.0, ymax=1024
# X wrong!!!: x=129090.0, xmax=1360
# Y wrong!!!: y=17716.0, ymax=1024
# X wrong!!!: x=129212.0, xmax=1360
# Y wrong!!!: y=17702.0, ymax=1024
# X wrong!!!: x=129342.0, xmax=1360
# Y wrong!!!: y=17691.0, ymax=1024
# X wrong!!!: x=129476.0, xmax=1360
# Y wrong!!!: y=17681.0, ymax=1024
# X wrong!!!: x=129616.0, xmax=1360
# Y wrong!!!: y=17673.0, ymax=1024
# X wrong!!!: x=129758.0, xmax=1360
# Y wrong!!!: y=17667.0, ymax=1024
# X wrong!!!: x=129902.0, xmax=1360
# Y wrong!!!: y=17664.0, ymax=1024
# X wrong!!!: x=130048.0, xmax=1360
# Y wrong!!!: y=17663.0, ymax=1024
# X wrong!!!: x=130194.0, xmax=1360
# Y wrong!!!: y=17664.0, ymax=1024
# X wrong!!!: x=130338.0, xmax=1360
# Y wrong!!!: y=17667.0, ymax=1024
# X wrong!!!: x=130480.0, xmax=1360
# Y wrong!!!: y=17673.0, ymax=1024
# X wrong!!!: x=130620.0, xmax=1360
# Y wrong!!!: y=17681.0, ymax=1024
# X wrong!!!: x=130754.0, xmax=1360
# Y wrong!!!: y=17691.0, ymax=1024
# X wrong!!!: x=130884.0, xmax=1360
# Y wrong!!!: y=17702.0, ymax=1024
# X wrong!!!: x=131006.0, xmax=1360
# Y wrong!!!: y=17716.0, ymax=1024
# X wrong!!!: x=131122.0, xmax=1360
# Y wrong!!!: y=17732.0, ymax=1024
# X wrong!!!: x=131230.0, xmax=1360
# Y wrong!!!: y=17749.0, ymax=1024
# X wrong!!!: x=131328.0, xmax=1360
# Y wrong!!!: y=17768.0, ymax=1024
# X wrong!!!: x=131417.0, xmax=1360
# Y wrong!!!: y=17788.0, ymax=1024
# X wrong!!!: x=131495.0, xmax=1360
# Y wrong!!!: y=17810.0, ymax=1024
# X wrong!!!: x=131562.0, xmax=1360
# Y wrong!!!: y=17833.0, ymax=1024
# X wrong!!!: x=131618.0, xmax=1360
# Y wrong!!!: y=17856.0, ymax=1024
# X wrong!!!: x=131662.0, xmax=1360
# Y wrong!!!: y=17881.0, ymax=1024
# X wrong!!!: x=131694.0, xmax=1360
# Y wrong!!!: y=17906.0, ymax=1024
# X wrong!!!: x=131713.0, xmax=1360
# Y wrong!!!: y=17931.0, ymax=1024
# X wrong!!!: x=131719.0, xmax=1360
# Y wrong!!!: y=17957.0, ymax=1024
# X wrong!!!: x=107853.0, xmax=1360
# Y wrong!!!: y=17815.0, ymax=1024
# X wrong!!!: x=107845.0, xmax=1360
# Y wrong!!!: y=17835.0, ymax=1024
# X wrong!!!: x=107823.0, xmax=1360
# Y wrong!!!: y=17855.0, ymax=1024
# X wrong!!!: x=107786.0, xmax=1360
# Y wrong!!!: y=17874.0, ymax=1024
# X wrong!!!: x=107734.0, xmax=1360
# Y wrong!!!: y=17893.0, ymax=1024
# X wrong!!!: x=107668.0, xmax=1360
# Y wrong!!!: y=17911.0, ymax=1024
# X wrong!!!: x=107588.0, xmax=1360
# Y wrong!!!: y=17929.0, ymax=1024
# X wrong!!!: x=107495.0, xmax=1360
# Y wrong!!!: y=17946.0, ymax=1024
# X wrong!!!: x=107390.0, xmax=1360
# Y wrong!!!: y=17962.0, ymax=1024
# X wrong!!!: x=107274.0, xmax=1360
# Y wrong!!!: y=17976.0, ymax=1024
# X wrong!!!: x=107147.0, xmax=1360
# Y wrong!!!: y=17990.0, ymax=1024
# X wrong!!!: x=107010.0, xmax=1360
# Y wrong!!!: y=18002.0, ymax=1024
# X wrong!!!: x=106864.0, xmax=1360
# Y wrong!!!: y=18012.0, ymax=1024
# X wrong!!!: x=106712.0, xmax=1360
# Y wrong!!!: y=18022.0, ymax=1024
# X wrong!!!: x=106552.0, xmax=1360
# Y wrong!!!: y=18029.0, ymax=1024
# X wrong!!!: x=106388.0, xmax=1360
# Y wrong!!!: y=18035.0, ymax=1024
# X wrong!!!: x=106219.0, xmax=1360
# Y wrong!!!: y=18040.0, ymax=1024
# X wrong!!!: x=106048.0, xmax=1360
# Y wrong!!!: y=18042.0, ymax=1024
# X wrong!!!: x=105876.0, xmax=1360
# Y wrong!!!: y=18043.0, ymax=1024
# X wrong!!!: x=105704.0, xmax=1360
# Y wrong!!!: y=18042.0, ymax=1024
# X wrong!!!: x=105533.0, xmax=1360
# Y wrong!!!: y=18040.0, ymax=1024
# X wrong!!!: x=105364.0, xmax=1360
# Y wrong!!!: y=18035.0, ymax=1024
# X wrong!!!: x=105200.0, xmax=1360
# Y wrong!!!: y=18029.0, ymax=1024
# X wrong!!!: x=105040.0, xmax=1360
# Y wrong!!!: y=18022.0, ymax=1024
# X wrong!!!: x=104888.0, xmax=1360
# Y wrong!!!: y=18012.0, ymax=1024
# X wrong!!!: x=104742.0, xmax=1360
# Y wrong!!!: y=18002.0, ymax=1024
# X wrong!!!: x=104605.0, xmax=1360
# Y wrong!!!: y=17990.0, ymax=1024
# X wrong!!!: x=104478.0, xmax=1360
# Y wrong!!!: y=17976.0, ymax=1024
# X wrong!!!: x=104362.0, xmax=1360
# Y wrong!!!: y=17962.0, ymax=1024
# X wrong!!!: x=104257.0, xmax=1360
# Y wrong!!!: y=17946.0, ymax=1024
# X wrong!!!: x=104164.0, xmax=1360
# Y wrong!!!: y=17929.0, ymax=1024
# X wrong!!!: x=104084.0, xmax=1360
# Y wrong!!!: y=17911.0, ymax=1024
# X wrong!!!: x=104018.0, xmax=1360
# Y wrong!!!: y=17893.0, ymax=1024
# X wrong!!!: x=103966.0, xmax=1360
# Y wrong!!!: y=17874.0, ymax=1024
# X wrong!!!: x=103929.0, xmax=1360
# Y wrong!!!: y=17855.0, ymax=1024
# X wrong!!!: x=103907.0, xmax=1360
# Y wrong!!!: y=17835.0, ymax=1024
# X wrong!!!: x=103899.0, xmax=1360
# Y wrong!!!: y=17815.0, ymax=1024
# X wrong!!!: x=103907.0, xmax=1360
# Y wrong!!!: y=17795.0, ymax=1024
# X wrong!!!: x=103929.0, xmax=1360
# Y wrong!!!: y=17775.0, ymax=1024
# X wrong!!!: x=103966.0, xmax=1360
# Y wrong!!!: y=17756.0, ymax=1024
# X wrong!!!: x=104018.0, xmax=1360
# Y wrong!!!: y=17737.0, ymax=1024
# X wrong!!!: x=104084.0, xmax=1360
# Y wrong!!!: y=17719.0, ymax=1024
# X wrong!!!: x=104164.0, xmax=1360
# Y wrong!!!: y=17701.0, ymax=1024
# X wrong!!!: x=104257.0, xmax=1360
# Y wrong!!!: y=17684.0, ymax=1024
# X wrong!!!: x=104362.0, xmax=1360
# Y wrong!!!: y=17668.0, ymax=1024
# X wrong!!!: x=104478.0, xmax=1360
# Y wrong!!!: y=17654.0, ymax=1024
# X wrong!!!: x=104605.0, xmax=1360
# Y wrong!!!: y=17640.0, ymax=1024
# X wrong!!!: x=104742.0, xmax=1360
# Y wrong!!!: y=17628.0, ymax=1024
# X wrong!!!: x=104888.0, xmax=1360
# Y wrong!!!: y=17618.0, ymax=1024
# X wrong!!!: x=105040.0, xmax=1360
# Y wrong!!!: y=17608.0, ymax=1024
# X wrong!!!: x=105200.0, xmax=1360
# Y wrong!!!: y=17601.0, ymax=1024
# X wrong!!!: x=105364.0, xmax=1360
